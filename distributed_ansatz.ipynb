# %%
import torch
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import pandas as pd
from datetime import datetime
import time

# # Assuming evaluate is defined elsewhere
# # from your_module import evaluate
import torch.optim as optim

from tqdm.auto import tqdm
from collections.abc import Iterable
import perceval as pcvl
from boson_sampler import BosonSampler
import numpy as np
from scipy.optimize import minimize
import random
import matplotlib.pyplot as plt
from utils import MNIST_partial, accuracy, plot_training_metrics
# from model import MnistModel, evaluate
import torch.nn as nn
import torch.nn.functional as F
# simulator = pcvl.Simulator(pcvl.NaiveBackend())
from scipy.optimize import minimize

import warnings
warnings.filterwarnings("ignore")

# %%
# device = torch.device("cpu")
device = torch.device("cuda:0")

# %%
#### START SCALEWAY SESSION ####
session = None
# to run a remote session on Scaleway, uncomment the following and fill project_id and token
# session = scw.Session(
#                    platform="sim:sampling:p100",  # or sim:sampling:h100
#                    project_id=""  # Your project id,
#                    token=""  # Your personal API key
#                    )

# start session
if session is not None:
    session.start()

#### BOSON SAMPLER DEFINITION ####

bs_1 = BosonSampler(m = 7, n = 4, postselect = 0, session = session)
print(f"Boson sampler defined with number of parameters = {bs_1.nb_parameters}, and embedding size = {bs_1.embedding_size}")
#to display it
pcvl.pdisplay(bs_1.create_circuit())
# Out:
# Boson sampler defined with number of parameters = 63, and embedding size = 35

# %%
bs_2 = BosonSampler(m = 7, n = 4, postselect = 0, session = session)
print(f"Boson sampler defined with number of parameters = {bs_2.nb_parameters}, and embedding size = {bs_2.embedding_size}")
#to display it
pcvl.pdisplay(bs_2.create_circuit())
# Out:
# Boson sampler defined with number of parameters = 63, and embedding size = 35

# %%
35 * 35
# Out:
# 1225

# %%
# random_para_tensor = torch.randn(165)
# res = bs.run(
#     parameters=random_para_tensor,
#     samples=100000
# )

# trans_res = bs.translate_results(res = res)
# print(trans_res)

# %%
# print(torch.mean(trans_res))

# trans_res = trans_res/torch.mean(trans_res)

# print(torch.mean(trans_res))

# %%
# count = 0
# for i in trans_res:
#     if i != 0:
#         count += 1
#     # print(i)
# print("non zero counts:", count)

# %%
# print(len(trans_res))

# %%
# Define the CNN model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 4, kernel_size=4)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(4, 4, kernel_size=4)
        self.fc1 = nn.Linear(4*4*4, 10)
        # self.fc2 = nn.Linear(20, 10)
        
    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1) # [N, 32 * 8 * 8]
        x = self.fc1(x)
        # x = self.fc2(x)
    #     super(CNNModel, self).__init__()
    #     self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
    #     self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
    #     self.conv2 = nn.Conv2d(8, 12, kernel_size=5)
    #     self.fc1 = nn.Linear(12*4*4, 20)
    #     self.fc2 = nn.Linear(20, 10)
        
    # def forward(self, x):
    #     x = self.pool(self.conv1(x))
    #     x = self.pool(self.conv2(x))
    #     x = x.view(x.size(0), -1) # [N, 32 * 8 * 8]
    #     x = self.fc1(x)
    #     x = self.fc2(x)
        return x
    
# dataset from csv file, to use for the challenge
train_dataset = MNIST_partial(split = 'train')
val_dataset = MNIST_partial(split='val')

# definition of the dataloader, to process the data in the model
# here, we need a batch size of 1 to use the boson sampler
batch_size = 128
train_loader = DataLoader(train_dataset, batch_size, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size, shuffle = False)

# %%
learning_rate = 1e-3
num_epochs = 1


# Instantiate the model and loss function
model = CNNModel()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

num_classical_parameter = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("# of parameters in classical CNN model: ", num_classical_parameter)
# Out:
# # of parameters in classical CNN model:  978

# %%
# Training loop
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")

# %%
# Testing loop
model.eval()
correct = 0
total = 0
loss_test_list = [] 
with torch.no_grad():
    for images, labels in val_loader:
        outputs = model(images)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
# Out:
# Accuracy on the test set: 54.67%

# %%
### required qubits estimation ##############
# NN weights

numpy_weights = {}
nw_list = [] 
nw_list_normal = []
for name, param in model.state_dict().items():
    numpy_weights[name] = param.cpu().numpy()
for i in numpy_weights:
    nw_list.append(list(numpy_weights[i].flatten()))
for i in nw_list:
    for j in i:
        nw_list_normal.append(j)
print("# of NN parameters: ", len(nw_list_normal))
n_qubits = int(np.ceil(np.log2(len(nw_list_normal))))
print("Required qubit number: ", n_qubits)

n_qubit = n_qubits

#############################################
# Out:
# # of NN parameters:  978
# Required qubit number:  10

# %%
# len(np.zeros(126)[63:])

# %%
### Some tool function definition ###########
def probs_to_weights(probs_):

    new_state_dict = {}
    data_iterator = probs_.view(-1)

    for name, param in CNNModel().state_dict().items():
        shape = param.shape
        num_elements = param.numel()
        chunk = data_iterator[:num_elements].reshape(shape)
        new_state_dict[name] = chunk
        data_iterator = data_iterator[num_elements:]
        
    return new_state_dict

def generate_qubit_states_torch(n_qubit):
    # Create a tensor of shape (2**n_qubit, n_qubit) with all possible combinations of 0 and 1
    all_states = torch.cartesian_prod(*[torch.tensor([-1, 1]) for _ in range(n_qubit)])
    return all_states

#############################################

### Main Learning-wise Hybridization model ##

class PhotonicQuantumTrain(nn.Module):

    class MappingModel(nn.Module):
        def __init__(self, input_size, hidden_sizes, output_size):
            super().__init__()
            # Initialize layers: an input layer, multiple hidden layers, and an output layer
            self.input_layer = nn.Linear(input_size, hidden_sizes[0])
            self.hidden_layers = nn.ModuleList([nn.Linear(hidden_sizes[i], hidden_sizes[i+1]) for i in range(len(hidden_sizes)-1)])
            self.output_layer = nn.Linear(hidden_sizes[-1], output_size)
            
        def forward(self, X):
            # Ensure the input tensor is the same type as the weights
            X = X.type_as(self.input_layer.weight)

            # Input layer with ReLU activation
            X = self.input_layer(X)

            # Hidden layers with ReLU activation
            for hidden in self.hidden_layers:
                X = hidden(X)

            # Output layer with linear activation
            output = self.output_layer(X)
            # output = F.tanh(output)  # It's often better to use ReLU or similar; tanh is used here as it was in the original model.
            return output

    def __init__(self):
        """
        """
        super().__init__()
        self.MappingNetwork = self.MappingModel(n_qubit+1, [20, 4], 1).to(device)  
        # self.MappingNetwork = self.ConvMappingModel()
        # self.QuantumNN = nn.parameter(135)

        #self.QLayer(q_depth).to(device)   #arch={"n_blocks": q_depth})
    
    def forward(self, x, qnn_parameters):
        """
        """
        self.q_params_1 = qnn_parameters[:63] #nn.Parameter(q_delta * torch.randn(135)).to(device)  
        self.q_params_2 = qnn_parameters[63:]
        device = x.device
        
        res_1 = bs_1.run(
            parameters=self.q_params_1,
            samples=100000
        )
        trans_res_1 = bs_1.translate_results(res = res_1)
        trans_res_1 = trans_res_1/torch.mean(trans_res_1)
        probs_1 = trans_res_1.to(device)  
        
        res_2 = bs_2.run(
            parameters=self.q_params_2,
            samples=100000
        )
        trans_res_2 = bs_2.translate_results(res = res_2)
        trans_res_2 = trans_res_2/torch.mean(trans_res_2)
        probs_2 = trans_res_2.to(device)  

        probs_ = torch.ger(probs_1, probs_2).flatten().reshape(35 * 35,1)  
        
        # probs_ = trans_res.to(device)  
        probs_ = probs_[:len(nw_list_normal)]
        probs_ = probs_.reshape(len(nw_list_normal),1)
        
        # Generate qubit states using PyTorch
        qubit_states_torch = generate_qubit_states_torch(n_qubit)[:len(nw_list_normal)]
        qubit_states_torch = qubit_states_torch.to(device)

        # Combine qubit states with probability values using PyTorch
        combined_data_torch = torch.cat((qubit_states_torch, probs_), dim=1)
        combined_data_torch = combined_data_torch.reshape(len(nw_list_normal), 1, n_qubit+1)
        
        prob_val_post_processed = self.MappingNetwork(combined_data_torch)
        prob_val_post_processed = prob_val_post_processed - prob_val_post_processed.mean()
        
        state_dict = probs_to_weights(prob_val_post_processed)

        ######## 
            
        dtype = torch.float32  # Ensure all tensors are of this type
        
        # Convolution layer 1 parameters
        conv1_weight = state_dict['conv1.weight'].to(device).type(dtype)
        conv1_bias = state_dict['conv1.bias'].to(device).type(dtype)

        # Convolution layer 2 parameters
        conv2_weight = state_dict['conv2.weight'].to(device).type(dtype)
        conv2_bias = state_dict['conv2.bias'].to(device).type(dtype)

        # Fully connected layer 1 parameters
        fc1_weight = state_dict['fc1.weight'].to(device).type(dtype)
        fc1_bias = state_dict['fc1.bias'].to(device).type(dtype)

        # # Fully connected layer 2 parameters
        # fc2_weight = state_dict['fc2.weight'].to(device).type(dtype)
        # fc2_bias = state_dict['fc2.bias'].to(device).type(dtype)
        
        
        # Convolution 1
        x = F.conv2d(x, conv1_weight, conv1_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Convolution 2
        x = F.conv2d(x, conv2_weight, conv2_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Flatten
        x = x.view(x.size(0), -1)

        # Fully connected 1
        x = F.linear(x, fc1_weight, fc1_bias)

        # # Fully connected 2
        # x = F.linear(x, fc2_weight, fc2_bias)

    
        return x

# %%
### Training setting ########################
num_epochs = 5
step = 1e-3               # Learning rate
# batch_size = 64       # Number of samples for each training step
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 2 * np.pi        # Phases are 2 pi periodic --> we get better expressivity by multiplying the values by 2 pi

# train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
# train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# test_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)
# test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

init_qnn_parameters = q_delta * np.random.rand(126)

qnn_parameters = init_qnn_parameters

# Instantiate the model, move it to GPU, and set up loss function and optimizer
qt_model = PhotonicQuantumTrain().to(device)
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(qt_model.parameters(), lr=step) #, weight_decay=1e-5, eps=1e-6)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5, verbose = True, factor = 0.5)  # 'min' because we're minimizing loss

# num_trainable_params_MM = sum(p.numel() for p in PhotonicQuantumTrain.MappingModel(n_qubit+1,  [20, 4], 1).parameters() if p.requires_grad)
# num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.ConvMappingModel().parameters() if p.requires_grad)
num_trainable_params = sum(p.numel() for p in qt_model.parameters() if p.requires_grad)
print("# of trainable parameter in Mapping model: ", num_trainable_params)
print("# of trainable parameter in QNN model: ", bs_1.nb_parameters + bs_2.nb_parameters)
print("# of trainable parameter in full model: ", num_trainable_params + bs_1.nb_parameters + bs_2.nb_parameters)
# Out:
# # of trainable parameter in Mapping model:  329
# # of trainable parameter in QNN model:  126
# # of trainable parameter in full model:  455

# %%
# # Get a single random batch
# train_iter = iter(train_loader)  # Create an iterator
# images, labels = next(train_iter) 

# print(labels)

# %%
num_training_rounds = 400
batch_size_qnn = 1000
train_loader_qnn = DataLoader(train_dataset, batch_size_qnn, shuffle = True)
# val_loader = DataLoader(val_dataset, batch_size, shuffle = False)

global images, labels

#############################################
### Training loop ###########################
#############################################

loss_list = [] 


for round_ in range(num_training_rounds): 
    print("-----------------------")
    
    acc_list = [] 
    acc_best = 0
    for epoch in range(num_epochs):
        qt_model.train()
        train_loss = 0
        for i, (images, labels) in enumerate(train_loader):
            correct = 0
            total = 0
            since_batch = time.time()
            
            images, labels = images.to(device), labels.to(device)  # Move data to GPU
            optimizer.zero_grad()
            # Forward pass
            outputs = qt_model(images, qnn_parameters = qnn_parameters)
            # print("output: ", outputs)
            labels_one_hot = F.one_hot(labels, num_classes=10).float()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            # Compute loss
            loss = criterion(outputs, labels_one_hot)
            # log_loss = torch.log(loss + 1e-6)
            
            loss_list.append(loss.cpu().detach().numpy())
            acc = 100 * correct / total
            acc_list.append(acc)
            train_loss += loss.cpu().detach().numpy()
            
            # np.array(loss_list).dump("L1/3/loss_list.dat")
            # np.array(acc_list).dump("L1/3/acc_list.dat")
            if acc > acc_best:
                # torch.save(model, 'L1/3/tq_mm_acc_'+str(int(acc))+'_bsf')
                acc_best = acc
            # Backward pass and optimization
            loss.backward()
            
            optimizer.step()
            if (i+1) % 20 == 0:
                print(f"Training round [{round_+1}/{num_training_rounds}], Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}, batch time: {time.time() - since_batch:.2f}, accuracy:  {(acc):.2f}%")
        
        train_loss /= len(train_loader)
        # scheduler.step(train_loss)
        
    #############################################


    num_batch_qnn = 1

    for batch_ in range(num_batch_qnn):
        # print(f"Training round [{round_+1}/{num_training_rounds}]")
        # print(f"Training round [{round_+1}/{num_training_rounds}], qnn batch {batch_ + 1}")
        global qnn_train_step
        qnn_train_step = 0 
        
        # Get a single random batch
        train_iter = iter(train_loader_qnn)  # Create an iterator
        images, labels = next(train_iter) 

        def qnn_minimize_loss(qnn_parameters_=None):
            global qnn_train_step
            global images, labels
            
            correct = 0
            total = 0
            
            images, labels = images.to(device), labels.to(device)  
            optimizer.zero_grad()
            # Forward pass
            outputs = qt_model(images, qnn_parameters = qnn_parameters_)
            labels_one_hot = F.one_hot(labels, num_classes=10).float()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            loss = criterion(outputs, labels_one_hot)
            loss = loss.cpu().detach().numpy()
            acc = 100 * correct / total
            loss_list.append(loss)
            
            qnn_train_step += 1 
            if qnn_train_step % 100 == 0:
                # print("qnn_train_step :", qnn_train_step, ", loss :", loss, ", acc : ", acc)
                print(f"Training round [{round_+1}/{num_training_rounds}], qnn_train_step: [{qnn_train_step}/{500}], loss: {loss}, accuracy: {acc} %")

            # print("qnn_parameters [:10] :", qnn_parameters_[:10])
            return loss


        # Nelder-Mead
        # COBYLA 
        # SLSQP

        init_param = qnn_parameters
        result = minimize(qnn_minimize_loss, init_param, method='COBYLA', options = {'maxiter': 500, 'adaptive': True, 'rhobeg': 0.5} )

        qnn_parameters = result.x
# Out:
# -----------------------
# Training round [1/400], Epoch [1/5], Step [20/47], Loss: 2.2953, batch time: 0.02, accuracy:  10.94%
# Training round [1/400], Epoch [1/5], Step [40/47], Loss: 2.2909, batch time: 0.02, accuracy:  25.00%
# Training round [1/400], Epoch [2/5], Step [20/47], Loss: 2.2394, batch time: 0.02, accuracy:  21.09%
# Training round [1/400], Epoch [2/5], Step [40/47], Loss: 2.2243, batch time: 0.02, accuracy:  25.00%
# Training round [1/400], Epoch [3/5], Step [20/47], Loss: 2.2822, batch time: 0.03, accuracy:  15.62%
# Training round [1/400], Epoch [3/5], Step [40/47], Loss: 2.2037, batch time: 0.03, accuracy:  20.31%
# Training round [1/400], Epoch [4/5], Step [20/47], Loss: 2.1564, batch time: 0.02, accuracy:  28.91%
# Training round [1/400], Epoch [4/5], Step [40/47], Loss: 2.0928, batch time: 0.02, accuracy:  29.69%
# Training round [1/400], Epoch [5/5], Step [20/47], Loss: 2.0283, batch time: 0.02, accuracy:  23.44%
# Training round [1/400], Epoch [5/5], Step [40/47], Loss: 2.0330, batch time: 0.02, accuracy:  22.66%
# Training round [1/400], qnn_train_step: [100/500], loss: 1.8805501461029053, accuracy: 32.9 %
# Training round [1/400], qnn_train_step: [200/500], loss: 1.894066572189331, accuracy: 33.1 %
# Training round [1/400], qnn_train_step: [300/500], loss: 1.8737975358963013, accuracy: 32.8 %
# Training round [1/400], qnn_train_step: [400/500], loss: 1.845073938369751, accuracy: 36.0 %
# Training round [1/400], qnn_train_step: [500/500], loss: 1.876282811164856, accuracy: 31.8 %
# -----------------------
# Training round [2/400], Epoch [1/5], Step [20/47], Loss: 1.9526, batch time: 0.02, accuracy:  28.12%
# Training round [2/400], Epoch [1/5], Step [40/47], Loss: 1.7237, batch time: 0.02, accuracy:  35.94%
# Training round [2/400], Epoch [2/5], Step [20/47], Loss: 1.6811, batch time: 0.02, accuracy:  41.41%
# Training round [2/400], Epoch [2/5], Step [40/47], Loss: 1.9627, batch time: 0.02, accuracy:  32.03%
# Training round [2/400], Epoch [3/5], Step [20/47], Loss: 1.9100, batch time: 0.02, accuracy:  32.81%
# Training round [2/400], Epoch [3/5], Step [40/47], Loss: 1.8241, batch time: 0.02, accuracy:  32.03%
# Training round [2/400], Epoch [4/5], Step [20/47], Loss: 1.8424, batch time: 0.02, accuracy:  39.06%
# Training round [2/400], Epoch [4/5], Step [40/47], Loss: 1.7614, batch time: 0.02, accuracy:  39.06%
# Training round [2/400], Epoch [5/5], Step [20/47], Loss: 1.5996, batch time: 0.02, accuracy:  44.53%
# Training round [2/400], Epoch [5/5], Step [40/47], Loss: 1.8246, batch time: 0.02, accuracy:  31.25%
# Training round [2/400], qnn_train_step: [100/500], loss: 1.8246943950653076, accuracy: 35.7 %
# Training round [2/400], qnn_train_step: [200/500], loss: 1.8212857246398926, accuracy: 34.7 %
# Training round [2/400], qnn_train_step: [300/500], loss: 1.8094149827957153, accuracy: 35.5 %
# Training round [2/400], qnn_train_step: [400/500], loss: 1.8063907623291016, accuracy: 35.4 %
# Training round [2/400], qnn_train_step: [500/500], loss: 1.8032379150390625, accuracy: 36.1 %
# -----------------------
# Training round [3/400], Epoch [1/5], Step [20/47], Loss: 1.9087, batch time: 0.02, accuracy:  32.81%
# Training round [3/400], Epoch [1/5], Step [40/47], Loss: 1.8167, batch time: 0.02, accuracy:  35.94%
# Training round [3/400], Epoch [2/5], Step [20/47], Loss: 1.7911, batch time: 0.02, accuracy:  32.81%
# Training round [3/400], Epoch [2/5], Step [40/47], Loss: 1.7000, batch time: 0.02, accuracy:  37.50%
# Training round [3/400], Epoch [3/5], Step [20/47], Loss: 1.8160, batch time: 0.02, accuracy:  32.81%
# Training round [3/400], Epoch [3/5], Step [40/47], Loss: 1.8505, batch time: 0.02, accuracy:  39.84%
# Training round [3/400], Epoch [4/5], Step [20/47], Loss: 1.8009, batch time: 0.02, accuracy:  35.94%
# Training round [3/400], Epoch [4/5], Step [40/47], Loss: 1.6614, batch time: 0.02, accuracy:  41.41%
# Training round [3/400], Epoch [5/5], Step [20/47], Loss: 1.9088, batch time: 0.02, accuracy:  32.03%
# Training round [3/400], Epoch [5/5], Step [40/47], Loss: 1.8451, batch time: 0.02, accuracy:  35.16%
# Training round [3/400], qnn_train_step: [100/500], loss: 1.7653658390045166, accuracy: 38.1 %
# Training round [3/400], qnn_train_step: [200/500], loss: 1.7487969398498535, accuracy: 38.6 %
# Training round [3/400], qnn_train_step: [300/500], loss: 1.740214228630066, accuracy: 39.0 %
# Training round [3/400], qnn_train_step: [400/500], loss: 1.7353719472885132, accuracy: 40.5 %
# Training round [3/400], qnn_train_step: [500/500], loss: 1.7330691814422607, accuracy: 39.3 %
# -----------------------
# Training round [4/400], Epoch [1/5], Step [20/47], Loss: 1.7703, batch time: 0.02, accuracy:  42.19%
# Training round [4/400], Epoch [1/5], Step [40/47], Loss: 1.6609, batch time: 0.04, accuracy:  43.75%
# Training round [4/400], Epoch [2/5], Step [20/47], Loss: 1.7971, batch time: 0.05, accuracy:  32.81%
# Training round [4/400], Epoch [2/5], Step [40/47], Loss: 1.8588, batch time: 0.05, accuracy:  41.41%
# Training round [4/400], Epoch [3/5], Step [20/47], Loss: 1.7122, batch time: 0.03, accuracy:  39.06%
# Training round [4/400], Epoch [3/5], Step [40/47], Loss: 1.6782, batch time: 0.06, accuracy:  39.84%
# Training round [4/400], Epoch [4/5], Step [20/47], Loss: 1.6409, batch time: 0.04, accuracy:  42.19%
# Training round [4/400], Epoch [4/5], Step [40/47], Loss: 1.7588, batch time: 0.02, accuracy:  34.38%
# Training round [4/400], Epoch [5/5], Step [20/47], Loss: 1.7511, batch time: 0.06, accuracy:  34.38%
# Training round [4/400], Epoch [5/5], Step [40/47], Loss: 1.7841, batch time: 0.02, accuracy:  43.75%
# Training round [4/400], qnn_train_step: [100/500], loss: 1.7897361516952515, accuracy: 37.3 %
# Training round [4/400], qnn_train_step: [200/500], loss: 1.7778801918029785, accuracy: 38.1 %
# Training round [4/400], qnn_train_step: [300/500], loss: 1.777044415473938, accuracy: 38.7 %
# Training round [4/400], qnn_train_step: [400/500], loss: 1.7781784534454346, accuracy: 38.1 %
# Training round [4/400], qnn_train_step: [500/500], loss: 1.766968846321106, accuracy: 40.2 %
# -----------------------
# Training round [5/400], Epoch [1/5], Step [20/47], Loss: 1.7420, batch time: 0.02, accuracy:  42.97%
# Training round [5/400], Epoch [1/5], Step [40/47], Loss: 1.7067, batch time: 0.02, accuracy:  39.84%
# Training round [5/400], Epoch [2/5], Step [20/47], Loss: 1.6724, batch time: 0.02, accuracy:  39.84%
# Training round [5/400], Epoch [2/5], Step [40/47], Loss: 1.7190, batch time: 0.02, accuracy:  39.06%
# Training round [5/400], Epoch [3/5], Step [20/47], Loss: 1.7991, batch time: 0.02, accuracy:  33.59%
# Training round [5/400], Epoch [3/5], Step [40/47], Loss: 1.6582, batch time: 0.02, accuracy:  46.09%
# Training round [5/400], Epoch [4/5], Step [20/47], Loss: 1.7605, batch time: 0.02, accuracy:  44.53%
# Training round [5/400], Epoch [4/5], Step [40/47], Loss: 1.6839, batch time: 0.02, accuracy:  46.09%
# Training round [5/400], Epoch [5/5], Step [20/47], Loss: 1.7551, batch time: 0.02, accuracy:  40.62%
# Training round [5/400], Epoch [5/5], Step [40/47], Loss: 1.6845, batch time: 0.02, accuracy:  39.06%
# Training round [5/400], qnn_train_step: [100/500], loss: 1.734027624130249, accuracy: 40.4 %
# Training round [5/400], qnn_train_step: [200/500], loss: 1.722560167312622, accuracy: 41.4 %
# Training round [5/400], qnn_train_step: [300/500], loss: 1.7190707921981812, accuracy: 41.6 %
# Training round [5/400], qnn_train_step: [400/500], loss: 1.7150533199310303, accuracy: 42.7 %
# Training round [5/400], qnn_train_step: [500/500], loss: 1.7155681848526, accuracy: 42.5 %
# -----------------------
# Training round [6/400], Epoch [1/5], Step [20/47], Loss: 1.8011, batch time: 0.02, accuracy:  38.28%
# Training round [6/400], Epoch [1/5], Step [40/47], Loss: 1.6253, batch time: 0.02, accuracy:  43.75%
# Training round [6/400], Epoch [2/5], Step [20/47], Loss: 1.5687, batch time: 0.02, accuracy:  48.44%
# Training round [6/400], Epoch [2/5], Step [40/47], Loss: 1.7143, batch time: 0.02, accuracy:  38.28%
# Training round [6/400], Epoch [3/5], Step [20/47], Loss: 1.6881, batch time: 0.02, accuracy:  42.19%
# Training round [6/400], Epoch [3/5], Step [40/47], Loss: 1.6993, batch time: 0.02, accuracy:  39.84%
# Training round [6/400], Epoch [4/5], Step [20/47], Loss: 1.7126, batch time: 0.02, accuracy:  44.53%
# Training round [6/400], Epoch [4/5], Step [40/47], Loss: 1.7984, batch time: 0.02, accuracy:  40.62%
# Training round [6/400], Epoch [5/5], Step [20/47], Loss: 1.6248, batch time: 0.02, accuracy:  44.53%
# Training round [6/400], Epoch [5/5], Step [40/47], Loss: 1.7322, batch time: 0.02, accuracy:  39.06%
# Training round [6/400], qnn_train_step: [100/500], loss: 1.7223297357559204, accuracy: 41.0 %
# Training round [6/400], qnn_train_step: [200/500], loss: 1.7077080011367798, accuracy: 41.1 %
# Training round [6/400], qnn_train_step: [300/500], loss: 1.714370846748352, accuracy: 41.5 %
# Training round [6/400], qnn_train_step: [400/500], loss: 1.7044647932052612, accuracy: 41.6 %
# Training round [6/400], qnn_train_step: [500/500], loss: 1.7025388479232788, accuracy: 40.9 %
# -----------------------
# Training round [7/400], Epoch [1/5], Step [20/47], Loss: 1.6602, batch time: 0.02, accuracy:  42.19%
# Training round [7/400], Epoch [1/5], Step [40/47], Loss: 1.6031, batch time: 0.02, accuracy:  43.75%
# Training round [7/400], Epoch [2/5], Step [20/47], Loss: 1.7127, batch time: 0.02, accuracy:  44.53%
# Training round [7/400], Epoch [2/5], Step [40/47], Loss: 1.6808, batch time: 0.02, accuracy:  41.41%
# Training round [7/400], Epoch [3/5], Step [20/47], Loss: 1.6037, batch time: 0.02, accuracy:  46.09%
# Training round [7/400], Epoch [3/5], Step [40/47], Loss: 1.6937, batch time: 0.02, accuracy:  40.62%
# Training round [7/400], Epoch [4/5], Step [20/47], Loss: 1.6111, batch time: 0.02, accuracy:  42.97%
# Training round [7/400], Epoch [4/5], Step [40/47], Loss: 1.6976, batch time: 0.02, accuracy:  43.75%
# Training round [7/400], Epoch [5/5], Step [20/47], Loss: 1.6129, batch time: 0.02, accuracy:  44.53%
# Training round [7/400], Epoch [5/5], Step [40/47], Loss: 1.6075, batch time: 0.02, accuracy:  41.41%
# Training round [7/400], qnn_train_step: [100/500], loss: 1.681260347366333, accuracy: 44.2 %
# Training round [7/400], qnn_train_step: [200/500], loss: 1.672078251838684, accuracy: 42.9 %
# Training round [7/400], qnn_train_step: [300/500], loss: 1.6599947214126587, accuracy: 43.7 %
# Training round [7/400], qnn_train_step: [400/500], loss: 1.6601382493972778, accuracy: 43.9 %
# Training round [7/400], qnn_train_step: [500/500], loss: 1.6571247577667236, accuracy: 44.6 %
# -----------------------
# Training round [8/400], Epoch [1/5], Step [20/47], Loss: 1.7433, batch time: 0.02, accuracy:  40.62%
# Training round [8/400], Epoch [1/5], Step [40/47], Loss: 1.6826, batch time: 0.02, accuracy:  41.41%
# Training round [8/400], Epoch [2/5], Step [20/47], Loss: 1.6183, batch time: 0.02, accuracy:  42.97%
# Training round [8/400], Epoch [2/5], Step [40/47], Loss: 1.6383, batch time: 0.02, accuracy:  46.09%
# Training round [8/400], Epoch [3/5], Step [20/47], Loss: 1.5164, batch time: 0.02, accuracy:  49.22%
# Training round [8/400], Epoch [3/5], Step [40/47], Loss: 1.6060, batch time: 0.02, accuracy:  50.00%
# Training round [8/400], Epoch [4/5], Step [20/47], Loss: 1.6973, batch time: 0.02, accuracy:  45.31%
# Training round [8/400], Epoch [4/5], Step [40/47], Loss: 1.7619, batch time: 0.02, accuracy:  44.53%
# Training round [8/400], Epoch [5/5], Step [20/47], Loss: 1.8599, batch time: 0.02, accuracy:  39.06%
# Training round [8/400], Epoch [5/5], Step [40/47], Loss: 1.5945, batch time: 0.02, accuracy:  45.31%
# Training round [8/400], qnn_train_step: [100/500], loss: 1.6557637453079224, accuracy: 44.3 %
# Training round [8/400], qnn_train_step: [200/500], loss: 1.634491205215454, accuracy: 44.8 %
# Training round [8/400], qnn_train_step: [300/500], loss: 1.6260966062545776, accuracy: 43.7 %
# Training round [8/400], qnn_train_step: [400/500], loss: 1.623187780380249, accuracy: 43.9 %
# Training round [8/400], qnn_train_step: [500/500], loss: 1.6271111965179443, accuracy: 43.8 %
# -----------------------
# Training round [9/400], Epoch [1/5], Step [20/47], Loss: 1.4842, batch time: 0.02, accuracy:  50.00%
# Training round [9/400], Epoch [1/5], Step [40/47], Loss: 1.6793, batch time: 0.02, accuracy:  49.22%
# Training round [9/400], Epoch [2/5], Step [20/47], Loss: 1.7179, batch time: 0.02, accuracy:  39.06%
# Training round [9/400], Epoch [2/5], Step [40/47], Loss: 1.6674, batch time: 0.02, accuracy:  45.31%
# Training round [9/400], Epoch [3/5], Step [20/47], Loss: 1.6481, batch time: 0.02, accuracy:  39.84%
# Training round [9/400], Epoch [3/5], Step [40/47], Loss: 1.6581, batch time: 0.02, accuracy:  44.53%
# Training round [9/400], Epoch [4/5], Step [20/47], Loss: 1.6501, batch time: 0.02, accuracy:  44.53%
# Training round [9/400], Epoch [4/5], Step [40/47], Loss: 1.7199, batch time: 0.02, accuracy:  39.06%
# Training round [9/400], Epoch [5/5], Step [20/47], Loss: 1.7296, batch time: 0.04, accuracy:  44.53%
# Training round [9/400], Epoch [5/5], Step [40/47], Loss: 1.6162, batch time: 0.02, accuracy:  43.75%
# Training round [9/400], qnn_train_step: [100/500], loss: 1.6641936302185059, accuracy: 43.2 %
# Training round [9/400], qnn_train_step: [200/500], loss: 1.646014928817749, accuracy: 43.5 %
# Training round [9/400], qnn_train_step: [300/500], loss: 1.655922770500183, accuracy: 43.6 %
# Training round [9/400], qnn_train_step: [400/500], loss: 1.6625250577926636, accuracy: 43.9 %
# Training round [9/400], qnn_train_step: [500/500], loss: 1.6508080959320068, accuracy: 42.6 %
# -----------------------
# Training round [10/400], Epoch [1/5], Step [20/47], Loss: 1.8050, batch time: 0.02, accuracy:  35.16%
# Training round [10/400], Epoch [1/5], Step [40/47], Loss: 1.5562, batch time: 0.02, accuracy:  48.44%
# Training round [10/400], Epoch [2/5], Step [20/47], Loss: 1.6730, batch time: 0.02, accuracy:  45.31%
# Training round [10/400], Epoch [2/5], Step [40/47], Loss: 1.6749, batch time: 0.03, accuracy:  47.66%
# Training round [10/400], Epoch [3/5], Step [20/47], Loss: 1.5525, batch time: 0.02, accuracy:  52.34%
# Training round [10/400], Epoch [3/5], Step [40/47], Loss: 1.6703, batch time: 0.02, accuracy:  42.97%
# Training round [10/400], Epoch [4/5], Step [20/47], Loss: 1.7196, batch time: 0.02, accuracy:  42.97%
# Training round [10/400], Epoch [4/5], Step [40/47], Loss: 1.5011, batch time: 0.02, accuracy:  47.66%
# Training round [10/400], Epoch [5/5], Step [20/47], Loss: 1.6649, batch time: 0.02, accuracy:  35.16%
# Training round [10/400], Epoch [5/5], Step [40/47], Loss: 1.7551, batch time: 0.02, accuracy:  45.31%
# Training round [10/400], qnn_train_step: [100/500], loss: 1.6913819313049316, accuracy: 41.4 %
# Training round [10/400], qnn_train_step: [200/500], loss: 1.6958636045455933, accuracy: 41.0 %
# Training round [10/400], qnn_train_step: [300/500], loss: 1.687030553817749, accuracy: 41.3 %
# Training round [10/400], qnn_train_step: [400/500], loss: 1.6847808361053467, accuracy: 41.2 %
# Training round [10/400], qnn_train_step: [500/500], loss: 1.6707569360733032, accuracy: 42.3 %
# -----------------------
# Training round [11/400], Epoch [1/5], Step [20/47], Loss: 1.7877, batch time: 0.02, accuracy:  39.84%
# Training round [11/400], Epoch [1/5], Step [40/47], Loss: 1.7656, batch time: 0.02, accuracy:  39.84%
# Training round [11/400], Epoch [2/5], Step [20/47], Loss: 1.6391, batch time: 0.02, accuracy:  44.53%
# Training round [11/400], Epoch [2/5], Step [40/47], Loss: 1.6252, batch time: 0.02, accuracy:  40.62%
# Training round [11/400], Epoch [3/5], Step [20/47], Loss: 1.5427, batch time: 0.02, accuracy:  38.28%
# Training round [11/400], Epoch [3/5], Step [40/47], Loss: 1.6984, batch time: 0.02, accuracy:  39.06%
# Training round [11/400], Epoch [4/5], Step [20/47], Loss: 1.8815, batch time: 0.02, accuracy:  39.06%
# Training round [11/400], Epoch [4/5], Step [40/47], Loss: 1.5971, batch time: 0.02, accuracy:  46.88%
# Training round [11/400], Epoch [5/5], Step [20/47], Loss: 1.5929, batch time: 0.02, accuracy:  48.44%
# Training round [11/400], Epoch [5/5], Step [40/47], Loss: 1.6011, batch time: 0.02, accuracy:  40.62%
# Training round [11/400], qnn_train_step: [100/500], loss: 1.6336053609848022, accuracy: 42.7 %
# Training round [11/400], qnn_train_step: [200/500], loss: 1.6149712800979614, accuracy: 43.7 %
# Training round [11/400], qnn_train_step: [300/500], loss: 1.61170494556427, accuracy: 43.8 %
# Training round [11/400], qnn_train_step: [400/500], loss: 1.6058011054992676, accuracy: 43.8 %
# Training round [11/400], qnn_train_step: [500/500], loss: 1.5985984802246094, accuracy: 45.1 %
# -----------------------
# Training round [12/400], Epoch [1/5], Step [20/47], Loss: 1.6522, batch time: 0.02, accuracy:  42.97%
# Training round [12/400], Epoch [1/5], Step [40/47], Loss: 1.6459, batch time: 0.02, accuracy:  42.97%
# Training round [12/400], Epoch [2/5], Step [20/47], Loss: 1.5916, batch time: 0.02, accuracy:  47.66%
# Training round [12/400], Epoch [2/5], Step [40/47], Loss: 1.5955, batch time: 0.02, accuracy:  42.19%
# Training round [12/400], Epoch [3/5], Step [20/47], Loss: 1.5973, batch time: 0.02, accuracy:  50.78%
# Training round [12/400], Epoch [3/5], Step [40/47], Loss: 1.4550, batch time: 0.02, accuracy:  48.44%
# Training round [12/400], Epoch [4/5], Step [20/47], Loss: 1.5800, batch time: 0.02, accuracy:  40.62%
# Training round [12/400], Epoch [4/5], Step [40/47], Loss: 1.5789, batch time: 0.02, accuracy:  42.97%
# Training round [12/400], Epoch [5/5], Step [20/47], Loss: 1.6466, batch time: 0.02, accuracy:  43.75%
# Training round [12/400], Epoch [5/5], Step [40/47], Loss: 1.5836, batch time: 0.02, accuracy:  41.41%
# Training round [12/400], qnn_train_step: [100/500], loss: 1.6616109609603882, accuracy: 44.3 %
# Training round [12/400], qnn_train_step: [200/500], loss: 1.6192446947097778, accuracy: 46.6 %
# Training round [12/400], qnn_train_step: [300/500], loss: 1.6273767948150635, accuracy: 47.3 %
# Training round [12/400], qnn_train_step: [400/500], loss: 1.614324688911438, accuracy: 46.8 %
# Training round [12/400], qnn_train_step: [500/500], loss: 1.6057989597320557, accuracy: 46.2 %
# -----------------------
# Training round [13/400], Epoch [1/5], Step [20/47], Loss: 1.6274, batch time: 0.03, accuracy:  44.53%
# Training round [13/400], Epoch [1/5], Step [40/47], Loss: 1.5565, batch time: 0.02, accuracy:  46.88%
# Training round [13/400], Epoch [2/5], Step [20/47], Loss: 1.8301, batch time: 0.02, accuracy:  35.16%
# Training round [13/400], Epoch [2/5], Step [40/47], Loss: 1.5538, batch time: 0.02, accuracy:  49.22%
# Training round [13/400], Epoch [3/5], Step [20/47], Loss: 1.5518, batch time: 0.02, accuracy:  47.66%
# Training round [13/400], Epoch [3/5], Step [40/47], Loss: 1.6385, batch time: 0.03, accuracy:  42.97%
# Training round [13/400], Epoch [4/5], Step [20/47], Loss: 1.6340, batch time: 0.02, accuracy:  46.09%
# Training round [13/400], Epoch [4/5], Step [40/47], Loss: 1.6906, batch time: 0.02, accuracy:  40.62%
# Training round [13/400], Epoch [5/5], Step [20/47], Loss: 1.6363, batch time: 0.02, accuracy:  44.53%
# Training round [13/400], Epoch [5/5], Step [40/47], Loss: 1.5154, batch time: 0.02, accuracy:  49.22%
# Training round [13/400], qnn_train_step: [100/500], loss: 1.6672935485839844, accuracy: 43.4 %
# Training round [13/400], qnn_train_step: [200/500], loss: 1.6546111106872559, accuracy: 44.8 %
# Training round [13/400], qnn_train_step: [300/500], loss: 1.6711091995239258, accuracy: 44.1 %
# Training round [13/400], qnn_train_step: [400/500], loss: 1.7099545001983643, accuracy: 42.7 %
# Training round [13/400], qnn_train_step: [500/500], loss: 1.6458369493484497, accuracy: 44.7 %
# -----------------------
# Training round [14/400], Epoch [1/5], Step [20/47], Loss: 1.7671, batch time: 0.02, accuracy:  39.84%
# Training round [14/400], Epoch [1/5], Step [40/47], Loss: 1.6710, batch time: 0.02, accuracy:  43.75%
# Training round [14/400], Epoch [2/5], Step [20/47], Loss: 1.5303, batch time: 0.03, accuracy:  45.31%
# Training round [14/400], Epoch [2/5], Step [40/47], Loss: 1.4711, batch time: 0.02, accuracy:  46.88%
# Training round [14/400], Epoch [3/5], Step [20/47], Loss: 1.7877, batch time: 0.02, accuracy:  36.72%
# Training round [14/400], Epoch [3/5], Step [40/47], Loss: 1.8267, batch time: 0.02, accuracy:  49.22%
# Training round [14/400], Epoch [4/5], Step [20/47], Loss: 1.5880, batch time: 0.02, accuracy:  41.41%
# Training round [14/400], Epoch [4/5], Step [40/47], Loss: 1.6908, batch time: 0.03, accuracy:  39.06%
# Training round [14/400], Epoch [5/5], Step [20/47], Loss: 1.6696, batch time: 0.02, accuracy:  45.31%
# Training round [14/400], Epoch [5/5], Step [40/47], Loss: 1.5153, batch time: 0.02, accuracy:  53.12%
# Training round [14/400], qnn_train_step: [100/500], loss: 1.6451512575149536, accuracy: 42.5 %
# Training round [14/400], qnn_train_step: [200/500], loss: 1.6289795637130737, accuracy: 43.7 %
# Training round [14/400], qnn_train_step: [300/500], loss: 1.6343040466308594, accuracy: 43.2 %
# Training round [14/400], qnn_train_step: [400/500], loss: 1.6306531429290771, accuracy: 44.2 %
# Training round [14/400], qnn_train_step: [500/500], loss: 1.6259759664535522, accuracy: 43.6 %
# -----------------------
# Training round [15/400], Epoch [1/5], Step [20/47], Loss: 1.6133, batch time: 0.02, accuracy:  39.84%
# Training round [15/400], Epoch [1/5], Step [40/47], Loss: 1.5331, batch time: 0.02, accuracy:  50.00%
# Training round [15/400], Epoch [2/5], Step [20/47], Loss: 1.5962, batch time: 0.02, accuracy:  44.53%
# Training round [15/400], Epoch [2/5], Step [40/47], Loss: 1.6931, batch time: 0.02, accuracy:  43.75%
# Training round [15/400], Epoch [3/5], Step [20/47], Loss: 1.6057, batch time: 0.03, accuracy:  47.66%
# Training round [15/400], Epoch [3/5], Step [40/47], Loss: 1.5894, batch time: 0.02, accuracy:  51.56%
# Training round [15/400], Epoch [4/5], Step [20/47], Loss: 1.5212, batch time: 0.02, accuracy:  46.88%
# Training round [15/400], Epoch [4/5], Step [40/47], Loss: 1.6862, batch time: 0.02, accuracy:  44.53%
# Training round [15/400], Epoch [5/5], Step [20/47], Loss: 1.6212, batch time: 0.02, accuracy:  45.31%
# Training round [15/400], Epoch [5/5], Step [40/47], Loss: 1.5700, batch time: 0.02, accuracy:  43.75%
# Training round [15/400], qnn_train_step: [100/500], loss: 1.6530176401138306, accuracy: 45.2 %
# Training round [15/400], qnn_train_step: [200/500], loss: 1.6438064575195312, accuracy: 44.9 %
# Training round [15/400], qnn_train_step: [300/500], loss: 1.6407356262207031, accuracy: 45.1 %
# Training round [15/400], qnn_train_step: [400/500], loss: 1.6414129734039307, accuracy: 44.5 %
# Training round [15/400], qnn_train_step: [500/500], loss: 1.6352852582931519, accuracy: 44.1 %
# -----------------------
# Training round [16/400], Epoch [1/5], Step [20/47], Loss: 1.5166, batch time: 0.02, accuracy:  44.53%
# Training round [16/400], Epoch [1/5], Step [40/47], Loss: 1.5980, batch time: 0.02, accuracy:  46.09%
# Training round [16/400], Epoch [2/5], Step [20/47], Loss: 1.6641, batch time: 0.02, accuracy:  43.75%
# Training round [16/400], Epoch [2/5], Step [40/47], Loss: 1.6447, batch time: 0.02, accuracy:  48.44%
# Training round [16/400], Epoch [3/5], Step [20/47], Loss: 1.6262, batch time: 0.02, accuracy:  35.16%
# Training round [16/400], Epoch [3/5], Step [40/47], Loss: 1.7805, batch time: 0.02, accuracy:  35.16%
# Training round [16/400], Epoch [4/5], Step [20/47], Loss: 1.5561, batch time: 0.02, accuracy:  51.56%
# Training round [16/400], Epoch [4/5], Step [40/47], Loss: 1.6047, batch time: 0.02, accuracy:  41.41%
# Training round [16/400], Epoch [5/5], Step [20/47], Loss: 1.7289, batch time: 0.02, accuracy:  39.84%
# Training round [16/400], Epoch [5/5], Step [40/47], Loss: 1.5975, batch time: 0.02, accuracy:  42.19%
# Training round [16/400], qnn_train_step: [100/500], loss: 1.5930328369140625, accuracy: 44.5 %
# Training round [16/400], qnn_train_step: [200/500], loss: 1.5889532566070557, accuracy: 45.8 %
# Training round [16/400], qnn_train_step: [300/500], loss: 1.5817893743515015, accuracy: 45.6 %
# Training round [16/400], qnn_train_step: [400/500], loss: 1.5770759582519531, accuracy: 46.0 %
# Training round [16/400], qnn_train_step: [500/500], loss: 1.5750887393951416, accuracy: 45.7 %
# -----------------------
# Training round [17/400], Epoch [1/5], Step [20/47], Loss: 1.5905, batch time: 0.02, accuracy:  42.19%
# Training round [17/400], Epoch [1/5], Step [40/47], Loss: 1.6324, batch time: 0.02, accuracy:  46.88%
# Training round [17/400], Epoch [2/5], Step [20/47], Loss: 1.5055, batch time: 0.02, accuracy:  44.53%
# Training round [17/400], Epoch [2/5], Step [40/47], Loss: 1.6080, batch time: 0.02, accuracy:  40.62%
# Training round [17/400], Epoch [3/5], Step [20/47], Loss: 1.6161, batch time: 0.02, accuracy:  47.66%
# Training round [17/400], Epoch [3/5], Step [40/47], Loss: 1.5675, batch time: 0.02, accuracy:  46.09%
# Training round [17/400], Epoch [4/5], Step [20/47], Loss: 1.6829, batch time: 0.02, accuracy:  53.12%
# Training round [17/400], Epoch [4/5], Step [40/47], Loss: 1.7859, batch time: 0.02, accuracy:  39.84%
# Training round [17/400], Epoch [5/5], Step [20/47], Loss: 1.5584, batch time: 0.02, accuracy:  41.41%
# Training round [17/400], Epoch [5/5], Step [40/47], Loss: 1.8138, batch time: 0.03, accuracy:  37.50%
# Training round [17/400], qnn_train_step: [100/500], loss: 1.5922163724899292, accuracy: 44.1 %
# Training round [17/400], qnn_train_step: [200/500], loss: 1.5882586240768433, accuracy: 44.9 %
# Training round [17/400], qnn_train_step: [300/500], loss: 1.596412181854248, accuracy: 45.3 %
# Training round [17/400], qnn_train_step: [400/500], loss: 1.5908421277999878, accuracy: 44.3 %
# Training round [17/400], qnn_train_step: [500/500], loss: 1.5974066257476807, accuracy: 44.5 %
# -----------------------
# Training round [18/400], Epoch [1/5], Step [20/47], Loss: 1.6381, batch time: 0.02, accuracy:  48.44%
# Training round [18/400], Epoch [1/5], Step [40/47], Loss: 1.5220, batch time: 0.02, accuracy:  47.66%
# Training round [18/400], Epoch [2/5], Step [20/47], Loss: 1.5207, batch time: 0.03, accuracy:  50.00%
# Training round [18/400], Epoch [2/5], Step [40/47], Loss: 1.5905, batch time: 0.02, accuracy:  45.31%
# Training round [18/400], Epoch [3/5], Step [20/47], Loss: 1.6039, batch time: 0.02, accuracy:  43.75%
# Training round [18/400], Epoch [3/5], Step [40/47], Loss: 1.6780, batch time: 0.02, accuracy:  40.62%
# Training round [18/400], Epoch [4/5], Step [20/47], Loss: 1.5338, batch time: 0.02, accuracy:  46.88%
# Training round [18/400], Epoch [4/5], Step [40/47], Loss: 1.6043, batch time: 0.02, accuracy:  46.09%
# Training round [18/400], Epoch [5/5], Step [20/47], Loss: 1.5944, batch time: 0.02, accuracy:  46.09%
# Training round [18/400], Epoch [5/5], Step [40/47], Loss: 1.5747, batch time: 0.02, accuracy:  46.09%
# Training round [18/400], qnn_train_step: [100/500], loss: 1.6333723068237305, accuracy: 44.9 %
# Training round [18/400], qnn_train_step: [200/500], loss: 1.6292833089828491, accuracy: 42.8 %
# Training round [18/400], qnn_train_step: [300/500], loss: 1.6359573602676392, accuracy: 43.3 %
# Training round [18/400], qnn_train_step: [400/500], loss: 1.6347301006317139, accuracy: 44.0 %
# Training round [18/400], qnn_train_step: [500/500], loss: 1.6185073852539062, accuracy: 44.7 %
# -----------------------
# Training round [19/400], Epoch [1/5], Step [20/47], Loss: 1.7581, batch time: 0.02, accuracy:  42.97%
# Training round [19/400], Epoch [1/5], Step [40/47], Loss: 1.5496, batch time: 0.02, accuracy:  42.97%
# Training round [19/400], Epoch [2/5], Step [20/47], Loss: 1.6526, batch time: 0.02, accuracy:  36.72%
# Training round [19/400], Epoch [2/5], Step [40/47], Loss: 1.5695, batch time: 0.02, accuracy:  47.66%
# Training round [19/400], Epoch [3/5], Step [20/47], Loss: 1.5989, batch time: 0.02, accuracy:  46.88%
# Training round [19/400], Epoch [3/5], Step [40/47], Loss: 1.5298, batch time: 0.02, accuracy:  50.00%
# Training round [19/400], Epoch [4/5], Step [20/47], Loss: 1.6117, batch time: 0.02, accuracy:  50.78%
# Training round [19/400], Epoch [4/5], Step [40/47], Loss: 1.6275, batch time: 0.02, accuracy:  50.78%
# Training round [19/400], Epoch [5/5], Step [20/47], Loss: 1.6171, batch time: 0.02, accuracy:  44.53%
# Training round [19/400], Epoch [5/5], Step [40/47], Loss: 1.5417, batch time: 0.02, accuracy:  47.66%
# Training round [19/400], qnn_train_step: [100/500], loss: 1.6034358739852905, accuracy: 45.5 %
# Training round [19/400], qnn_train_step: [200/500], loss: 1.6000442504882812, accuracy: 45.5 %
# Training round [19/400], qnn_train_step: [300/500], loss: 1.598205804824829, accuracy: 46.2 %
# Training round [19/400], qnn_train_step: [400/500], loss: 1.596229076385498, accuracy: 45.3 %
# Training round [19/400], qnn_train_step: [500/500], loss: 1.6016302108764648, accuracy: 44.8 %
# -----------------------
# Training round [20/400], Epoch [1/5], Step [20/47], Loss: 1.6098, batch time: 0.02, accuracy:  47.66%
# Training round [20/400], Epoch [1/5], Step [40/47], Loss: 1.5981, batch time: 0.02, accuracy:  46.09%
# Training round [20/400], Epoch [2/5], Step [20/47], Loss: 1.7159, batch time: 0.02, accuracy:  47.66%
# Training round [20/400], Epoch [2/5], Step [40/47], Loss: 1.5353, batch time: 0.03, accuracy:  51.56%
# Training round [20/400], Epoch [3/5], Step [20/47], Loss: 1.7486, batch time: 0.02, accuracy:  38.28%
# Training round [20/400], Epoch [3/5], Step [40/47], Loss: 1.5909, batch time: 0.02, accuracy:  43.75%
# Training round [20/400], Epoch [4/5], Step [20/47], Loss: 1.5752, batch time: 0.03, accuracy:  44.53%
# Training round [20/400], Epoch [4/5], Step [40/47], Loss: 1.7704, batch time: 0.02, accuracy:  44.53%
# Training round [20/400], Epoch [5/5], Step [20/47], Loss: 1.5721, batch time: 0.03, accuracy:  48.44%
# Training round [20/400], Epoch [5/5], Step [40/47], Loss: 1.5086, batch time: 0.02, accuracy:  46.09%
# Training round [20/400], qnn_train_step: [100/500], loss: 1.5927190780639648, accuracy: 46.5 %
# Training round [20/400], qnn_train_step: [200/500], loss: 1.588481068611145, accuracy: 46.1 %
# Training round [20/400], qnn_train_step: [300/500], loss: 1.5887020826339722, accuracy: 46.0 %
# Training round [20/400], qnn_train_step: [400/500], loss: 1.6417622566223145, accuracy: 41.4 %
# Training round [20/400], qnn_train_step: [500/500], loss: 1.5790268182754517, accuracy: 46.1 %
# -----------------------
# Training round [21/400], Epoch [1/5], Step [20/47], Loss: 1.6339, batch time: 0.02, accuracy:  42.97%
# Training round [21/400], Epoch [1/5], Step [40/47], Loss: 1.5781, batch time: 0.02, accuracy:  43.75%
# Training round [21/400], Epoch [2/5], Step [20/47], Loss: 1.5930, batch time: 0.02, accuracy:  42.19%
# Training round [21/400], Epoch [2/5], Step [40/47], Loss: 1.6107, batch time: 0.02, accuracy:  40.62%
# Training round [21/400], Epoch [3/5], Step [20/47], Loss: 1.5293, batch time: 0.02, accuracy:  46.09%
# Training round [21/400], Epoch [3/5], Step [40/47], Loss: 1.5814, batch time: 0.02, accuracy:  44.53%
# Training round [21/400], Epoch [4/5], Step [20/47], Loss: 1.5539, batch time: 0.02, accuracy:  50.78%
# Training round [21/400], Epoch [4/5], Step [40/47], Loss: 1.5728, batch time: 0.02, accuracy:  49.22%
# Training round [21/400], Epoch [5/5], Step [20/47], Loss: 1.5525, batch time: 0.02, accuracy:  46.09%
# Training round [21/400], Epoch [5/5], Step [40/47], Loss: 1.5863, batch time: 0.02, accuracy:  39.84%
# Training round [21/400], qnn_train_step: [100/500], loss: 1.5651172399520874, accuracy: 47.1 %
# Training round [21/400], qnn_train_step: [200/500], loss: 1.564092993736267, accuracy: 46.2 %
# Training round [21/400], qnn_train_step: [300/500], loss: 1.5868895053863525, accuracy: 41.6 %
# Training round [21/400], qnn_train_step: [400/500], loss: 1.61509370803833, accuracy: 44.0 %
# Training round [21/400], qnn_train_step: [500/500], loss: 1.5504883527755737, accuracy: 46.6 %
# -----------------------
# Training round [22/400], Epoch [1/5], Step [20/47], Loss: 1.6530, batch time: 0.02, accuracy:  45.31%
# Training round [22/400], Epoch [1/5], Step [40/47], Loss: 1.4827, batch time: 0.02, accuracy:  48.44%
# Training round [22/400], Epoch [2/5], Step [20/47], Loss: 1.4999, batch time: 0.03, accuracy:  49.22%
# Training round [22/400], Epoch [2/5], Step [40/47], Loss: 1.4547, batch time: 0.03, accuracy:  48.44%
# Training round [22/400], Epoch [3/5], Step [20/47], Loss: 1.7153, batch time: 0.03, accuracy:  44.53%
# Training round [22/400], Epoch [3/5], Step [40/47], Loss: 1.5560, batch time: 0.03, accuracy:  48.44%
# Training round [22/400], Epoch [4/5], Step [20/47], Loss: 1.6644, batch time: 0.03, accuracy:  44.53%
# Training round [22/400], Epoch [4/5], Step [40/47], Loss: 1.6180, batch time: 0.05, accuracy:  46.09%
# Training round [22/400], Epoch [5/5], Step [20/47], Loss: 1.5942, batch time: 0.03, accuracy:  50.78%
# Training round [22/400], Epoch [5/5], Step [40/47], Loss: 1.6673, batch time: 0.02, accuracy:  41.41%
# Training round [22/400], qnn_train_step: [100/500], loss: 1.6050524711608887, accuracy: 45.3 %
# Training round [22/400], qnn_train_step: [200/500], loss: 1.602820634841919, accuracy: 45.2 %
# Training round [22/400], qnn_train_step: [300/500], loss: 1.6001770496368408, accuracy: 45.7 %
# Training round [22/400], qnn_train_step: [400/500], loss: 1.6268057823181152, accuracy: 43.6 %
# Training round [22/400], qnn_train_step: [500/500], loss: 1.6074998378753662, accuracy: 43.7 %
# -----------------------
# Training round [23/400], Epoch [1/5], Step [20/47], Loss: 1.7587, batch time: 0.02, accuracy:  40.62%
# Training round [23/400], Epoch [1/5], Step [40/47], Loss: 1.6310, batch time: 0.02, accuracy:  46.88%
# Training round [23/400], Epoch [2/5], Step [20/47], Loss: 1.5157, batch time: 0.02, accuracy:  44.53%
# Training round [23/400], Epoch [2/5], Step [40/47], Loss: 1.6002, batch time: 0.02, accuracy:  44.53%
# Training round [23/400], Epoch [3/5], Step [20/47], Loss: 1.7274, batch time: 0.02, accuracy:  45.31%
# Training round [23/400], Epoch [3/5], Step [40/47], Loss: 1.5742, batch time: 0.02, accuracy:  42.19%
# Training round [23/400], Epoch [4/5], Step [20/47], Loss: 1.5639, batch time: 0.03, accuracy:  46.09%
# Training round [23/400], Epoch [4/5], Step [40/47], Loss: 1.5132, batch time: 0.06, accuracy:  46.88%
# Training round [23/400], Epoch [5/5], Step [20/47], Loss: 1.5002, batch time: 0.05, accuracy:  55.47%
# Training round [23/400], Epoch [5/5], Step [40/47], Loss: 1.6052, batch time: 0.06, accuracy:  44.53%
# Training round [23/400], qnn_train_step: [100/500], loss: 1.5886616706848145, accuracy: 46.0 %
# Training round [23/400], qnn_train_step: [200/500], loss: 1.5847830772399902, accuracy: 48.2 %
# Training round [23/400], qnn_train_step: [300/500], loss: 1.5777002573013306, accuracy: 45.9 %
# Training round [23/400], qnn_train_step: [400/500], loss: 1.5570794343948364, accuracy: 47.4 %
# Training round [23/400], qnn_train_step: [500/500], loss: 1.6495652198791504, accuracy: 38.9 %
# -----------------------
# Training round [24/400], Epoch [1/5], Step [20/47], Loss: 1.6778, batch time: 0.02, accuracy:  41.41%
# Training round [24/400], Epoch [1/5], Step [40/47], Loss: 1.6314, batch time: 0.03, accuracy:  46.09%
# Training round [24/400], Epoch [2/5], Step [20/47], Loss: 1.5016, batch time: 0.02, accuracy:  42.19%
# Training round [24/400], Epoch [2/5], Step [40/47], Loss: 1.4454, batch time: 0.02, accuracy:  51.56%
# Training round [24/400], Epoch [3/5], Step [20/47], Loss: 1.5362, batch time: 0.02, accuracy:  51.56%
# Training round [24/400], Epoch [3/5], Step [40/47], Loss: 1.6749, batch time: 0.02, accuracy:  40.62%
# Training round [24/400], Epoch [4/5], Step [20/47], Loss: 1.7833, batch time: 0.02, accuracy:  40.62%
# Training round [24/400], Epoch [4/5], Step [40/47], Loss: 1.6442, batch time: 0.02, accuracy:  43.75%
# Training round [24/400], Epoch [5/5], Step [20/47], Loss: 1.5939, batch time: 0.03, accuracy:  45.31%
# Training round [24/400], Epoch [5/5], Step [40/47], Loss: 1.4864, batch time: 0.02, accuracy:  57.03%
# Training round [24/400], qnn_train_step: [100/500], loss: 1.5876423120498657, accuracy: 44.3 %
# Training round [24/400], qnn_train_step: [200/500], loss: 1.5821335315704346, accuracy: 44.6 %
# Training round [24/400], qnn_train_step: [300/500], loss: 1.5845052003860474, accuracy: 44.3 %
# Training round [24/400], qnn_train_step: [400/500], loss: 1.6043555736541748, accuracy: 43.8 %
# Training round [24/400], qnn_train_step: [500/500], loss: 1.5710015296936035, accuracy: 46.0 %
# -----------------------
# Training round [25/400], Epoch [1/5], Step [20/47], Loss: 1.5113, batch time: 0.02, accuracy:  46.09%
# Training round [25/400], Epoch [1/5], Step [40/47], Loss: 1.5374, batch time: 0.02, accuracy:  46.09%
# Training round [25/400], Epoch [2/5], Step [20/47], Loss: 1.6663, batch time: 0.02, accuracy:  41.41%
# Training round [25/400], Epoch [2/5], Step [40/47], Loss: 1.6611, batch time: 0.02, accuracy:  44.53%
# Training round [25/400], Epoch [3/5], Step [20/47], Loss: 1.7649, batch time: 0.02, accuracy:  42.97%
# Training round [25/400], Epoch [3/5], Step [40/47], Loss: 1.5435, batch time: 0.02, accuracy:  50.00%
# Training round [25/400], Epoch [4/5], Step [20/47], Loss: 1.4256, batch time: 0.02, accuracy:  48.44%
# Training round [25/400], Epoch [4/5], Step [40/47], Loss: 1.4375, batch time: 0.02, accuracy:  60.16%
# Training round [25/400], Epoch [5/5], Step [20/47], Loss: 1.6889, batch time: 0.02, accuracy:  45.31%
# Training round [25/400], Epoch [5/5], Step [40/47], Loss: 1.4473, batch time: 0.02, accuracy:  54.69%
# Training round [25/400], qnn_train_step: [100/500], loss: 1.5494123697280884, accuracy: 48.6 %
# Training round [25/400], qnn_train_step: [200/500], loss: 1.5393116474151611, accuracy: 47.9 %
# Training round [25/400], qnn_train_step: [300/500], loss: 1.541904091835022, accuracy: 44.7 %
# Training round [25/400], qnn_train_step: [400/500], loss: 1.6114482879638672, accuracy: 41.7 %
# Training round [25/400], qnn_train_step: [500/500], loss: 1.526782751083374, accuracy: 49.1 %
# -----------------------
# Training round [26/400], Epoch [1/5], Step [20/47], Loss: 1.6418, batch time: 0.06, accuracy:  42.97%
# Training round [26/400], Epoch [1/5], Step [40/47], Loss: 1.6541, batch time: 0.06, accuracy:  44.53%
# Training round [26/400], Epoch [2/5], Step [20/47], Loss: 1.7883, batch time: 0.06, accuracy:  44.53%
# Training round [26/400], Epoch [2/5], Step [40/47], Loss: 1.6097, batch time: 0.06, accuracy:  43.75%
# Training round [26/400], Epoch [3/5], Step [20/47], Loss: 1.5929, batch time: 0.06, accuracy:  48.44%
# Training round [26/400], Epoch [3/5], Step [40/47], Loss: 1.6165, batch time: 0.06, accuracy:  46.88%
# Training round [26/400], Epoch [4/5], Step [20/47], Loss: 1.6714, batch time: 0.06, accuracy:  49.22%
# Training round [26/400], Epoch [4/5], Step [40/47], Loss: 1.5956, batch time: 0.06, accuracy:  46.88%
# Training round [26/400], Epoch [5/5], Step [20/47], Loss: 1.6324, batch time: 0.02, accuracy:  42.97%
# Training round [26/400], Epoch [5/5], Step [40/47], Loss: 1.7175, batch time: 0.02, accuracy:  41.41%
# Training round [26/400], qnn_train_step: [100/500], loss: 1.550935983657837, accuracy: 48.7 %
# Training round [26/400], qnn_train_step: [200/500], loss: 1.553851842880249, accuracy: 47.9 %
# Training round [26/400], qnn_train_step: [300/500], loss: 1.5732501745224, accuracy: 47.0 %
# Training round [26/400], qnn_train_step: [400/500], loss: 1.6515791416168213, accuracy: 46.1 %
# Training round [26/400], qnn_train_step: [500/500], loss: 1.5389595031738281, accuracy: 48.6 %
# -----------------------
# Training round [27/400], Epoch [1/5], Step [20/47], Loss: 1.5288, batch time: 0.02, accuracy:  47.66%
# Training round [27/400], Epoch [1/5], Step [40/47], Loss: 1.5212, batch time: 0.06, accuracy:  50.78%
# Training round [27/400], Epoch [2/5], Step [20/47], Loss: 1.5495, batch time: 0.06, accuracy:  42.97%
# Training round [27/400], Epoch [2/5], Step [40/47], Loss: 1.4835, batch time: 0.06, accuracy:  47.66%
# Training round [27/400], Epoch [3/5], Step [20/47], Loss: 1.5972, batch time: 0.06, accuracy:  46.88%
# Training round [27/400], Epoch [3/5], Step [40/47], Loss: 1.6461, batch time: 0.03, accuracy:  45.31%
# Training round [27/400], Epoch [4/5], Step [20/47], Loss: 1.6082, batch time: 0.02, accuracy:  51.56%
# Training round [27/400], Epoch [4/5], Step [40/47], Loss: 1.5615, batch time: 0.02, accuracy:  47.66%
# Training round [27/400], Epoch [5/5], Step [20/47], Loss: 1.3899, batch time: 0.02, accuracy:  58.59%
# Training round [27/400], Epoch [5/5], Step [40/47], Loss: 1.6953, batch time: 0.02, accuracy:  41.41%
# Training round [27/400], qnn_train_step: [100/500], loss: 1.5855846405029297, accuracy: 46.7 %
# Training round [27/400], qnn_train_step: [200/500], loss: 1.5867152214050293, accuracy: 47.3 %
# Training round [27/400], qnn_train_step: [300/500], loss: 1.6020746231079102, accuracy: 46.3 %
# Training round [27/400], qnn_train_step: [400/500], loss: 1.5907065868377686, accuracy: 46.4 %
# Training round [27/400], qnn_train_step: [500/500], loss: 1.5875550508499146, accuracy: 47.9 %
# -----------------------
# Training round [28/400], Epoch [1/5], Step [20/47], Loss: 1.4686, batch time: 0.06, accuracy:  49.22%
# Training round [28/400], Epoch [1/5], Step [40/47], Loss: 1.5164, batch time: 0.02, accuracy:  46.88%
# Training round [28/400], Epoch [2/5], Step [20/47], Loss: 1.4650, batch time: 0.02, accuracy:  53.12%
# Training round [28/400], Epoch [2/5], Step [40/47], Loss: 1.6050, batch time: 0.03, accuracy:  46.88%
# Training round [28/400], Epoch [3/5], Step [20/47], Loss: 1.5458, batch time: 0.02, accuracy:  49.22%
# Training round [28/400], Epoch [3/5], Step [40/47], Loss: 1.6044, batch time: 0.02, accuracy:  43.75%
# Training round [28/400], Epoch [4/5], Step [20/47], Loss: 1.5282, batch time: 0.02, accuracy:  50.78%
# Training round [28/400], Epoch [4/5], Step [40/47], Loss: 1.4648, batch time: 0.06, accuracy:  53.12%
# Training round [28/400], Epoch [5/5], Step [20/47], Loss: 1.4358, batch time: 0.06, accuracy:  46.09%
# Training round [28/400], Epoch [5/5], Step [40/47], Loss: 1.5376, batch time: 0.02, accuracy:  50.00%
# Training round [28/400], qnn_train_step: [100/500], loss: 1.567042350769043, accuracy: 48.0 %
# Training round [28/400], qnn_train_step: [200/500], loss: 1.5619279146194458, accuracy: 48.9 %
# Training round [28/400], qnn_train_step: [300/500], loss: 1.5719759464263916, accuracy: 46.6 %
# Training round [28/400], qnn_train_step: [400/500], loss: 1.5652087926864624, accuracy: 48.0 %
# Training round [28/400], qnn_train_step: [500/500], loss: 1.5569231510162354, accuracy: 49.3 %
# -----------------------
# Training round [29/400], Epoch [1/5], Step [20/47], Loss: 1.4693, batch time: 0.03, accuracy:  50.78%
# Training round [29/400], Epoch [1/5], Step [40/47], Loss: 1.5798, batch time: 0.02, accuracy:  44.53%
# Training round [29/400], Epoch [2/5], Step [20/47], Loss: 1.5040, batch time: 0.02, accuracy:  50.78%
# Training round [29/400], Epoch [2/5], Step [40/47], Loss: 1.5364, batch time: 0.02, accuracy:  52.34%
# Training round [29/400], Epoch [3/5], Step [20/47], Loss: 1.5459, batch time: 0.06, accuracy:  45.31%
# Training round [29/400], Epoch [3/5], Step [40/47], Loss: 1.5448, batch time: 0.05, accuracy:  53.91%
# Training round [29/400], Epoch [4/5], Step [20/47], Loss: 1.3681, batch time: 0.06, accuracy:  52.34%
# Training round [29/400], Epoch [4/5], Step [40/47], Loss: 1.6094, batch time: 0.02, accuracy:  43.75%
# Training round [29/400], Epoch [5/5], Step [20/47], Loss: 1.7194, batch time: 0.03, accuracy:  44.53%
# Training round [29/400], Epoch [5/5], Step [40/47], Loss: 1.4838, batch time: 0.02, accuracy:  60.16%
# Training round [29/400], qnn_train_step: [100/500], loss: 1.6167317628860474, accuracy: 46.3 %
# Training round [29/400], qnn_train_step: [200/500], loss: 1.614569902420044, accuracy: 44.4 %
# Training round [29/400], qnn_train_step: [300/500], loss: 1.6392853260040283, accuracy: 43.9 %
# Training round [29/400], qnn_train_step: [400/500], loss: 1.6055580377578735, accuracy: 47.0 %
# Training round [29/400], qnn_train_step: [500/500], loss: 1.601000428199768, accuracy: 46.6 %
# -----------------------
# Training round [30/400], Epoch [1/5], Step [20/47], Loss: 1.4642, batch time: 0.03, accuracy:  50.00%
# Training round [30/400], Epoch [1/5], Step [40/47], Loss: 1.6963, batch time: 0.02, accuracy:  44.53%
# Training round [30/400], Epoch [2/5], Step [20/47], Loss: 1.6881, batch time: 0.02, accuracy:  45.31%
# Training round [30/400], Epoch [2/5], Step [40/47], Loss: 1.4552, batch time: 0.02, accuracy:  51.56%
# Training round [30/400], Epoch [3/5], Step [20/47], Loss: 1.4586, batch time: 0.03, accuracy:  50.78%
# Training round [30/400], Epoch [3/5], Step [40/47], Loss: 1.5868, batch time: 0.02, accuracy:  46.88%
# Training round [30/400], Epoch [4/5], Step [20/47], Loss: 1.4434, batch time: 0.02, accuracy:  56.25%
# Training round [30/400], Epoch [4/5], Step [40/47], Loss: 1.5233, batch time: 0.03, accuracy:  50.78%
# Training round [30/400], Epoch [5/5], Step [20/47], Loss: 1.4474, batch time: 0.02, accuracy:  51.56%
# Training round [30/400], Epoch [5/5], Step [40/47], Loss: 1.5455, batch time: 0.02, accuracy:  44.53%
# Training round [30/400], qnn_train_step: [100/500], loss: 1.5517510175704956, accuracy: 48.1 %
# Training round [30/400], qnn_train_step: [200/500], loss: 1.5852497816085815, accuracy: 45.2 %
# Training round [30/400], qnn_train_step: [300/500], loss: 1.5418777465820312, accuracy: 48.7 %
# Training round [30/400], qnn_train_step: [400/500], loss: 1.5778974294662476, accuracy: 44.7 %
# Training round [30/400], qnn_train_step: [500/500], loss: 1.5381895303726196, accuracy: 49.5 %
# -----------------------
# Training round [31/400], Epoch [1/5], Step [20/47], Loss: 1.7155, batch time: 0.02, accuracy:  46.09%
# Training round [31/400], Epoch [1/5], Step [40/47], Loss: 1.5858, batch time: 0.02, accuracy:  49.22%
# Training round [31/400], Epoch [2/5], Step [20/47], Loss: 1.6297, batch time: 0.03, accuracy:  42.19%
# Training round [31/400], Epoch [2/5], Step [40/47], Loss: 1.6703, batch time: 0.02, accuracy:  47.66%
# Training round [31/400], Epoch [3/5], Step [20/47], Loss: 1.7278, batch time: 0.02, accuracy:  47.66%
# Training round [31/400], Epoch [3/5], Step [40/47], Loss: 1.5666, batch time: 0.03, accuracy:  50.00%
# Training round [31/400], Epoch [4/5], Step [20/47], Loss: 1.6237, batch time: 0.02, accuracy:  46.88%
# Training round [31/400], Epoch [4/5], Step [40/47], Loss: 1.5031, batch time: 0.03, accuracy:  46.09%
# Training round [31/400], Epoch [5/5], Step [20/47], Loss: 1.6094, batch time: 0.02, accuracy:  47.66%
# Training round [31/400], Epoch [5/5], Step [40/47], Loss: 1.5025, batch time: 0.02, accuracy:  54.69%
# Training round [31/400], qnn_train_step: [100/500], loss: 1.523449182510376, accuracy: 48.6 %
# Training round [31/400], qnn_train_step: [200/500], loss: 1.518976092338562, accuracy: 51.0 %
# Training round [31/400], qnn_train_step: [300/500], loss: 1.517500877380371, accuracy: 50.6 %
# Training round [31/400], qnn_train_step: [400/500], loss: 1.5118931531906128, accuracy: 50.4 %
# Training round [31/400], qnn_train_step: [500/500], loss: 1.5121610164642334, accuracy: 50.1 %
# -----------------------
# Training round [32/400], Epoch [1/5], Step [20/47], Loss: 1.4667, batch time: 0.03, accuracy:  53.91%
# Training round [32/400], Epoch [1/5], Step [40/47], Loss: 1.4489, batch time: 0.02, accuracy:  55.47%
# Training round [32/400], Epoch [2/5], Step [20/47], Loss: 1.4572, batch time: 0.02, accuracy:  54.69%
# Training round [32/400], Epoch [2/5], Step [40/47], Loss: 1.8514, batch time: 0.06, accuracy:  46.09%
# Training round [32/400], Epoch [3/5], Step [20/47], Loss: 1.4980, batch time: 0.03, accuracy:  51.56%
# Training round [32/400], Epoch [3/5], Step [40/47], Loss: 1.6270, batch time: 0.02, accuracy:  48.44%
# Training round [32/400], Epoch [4/5], Step [20/47], Loss: 1.5759, batch time: 0.02, accuracy:  46.09%
# Training round [32/400], Epoch [4/5], Step [40/47], Loss: 1.5109, batch time: 0.02, accuracy:  52.34%
# Training round [32/400], Epoch [5/5], Step [20/47], Loss: 1.3796, batch time: 0.02, accuracy:  49.22%
# Training round [32/400], Epoch [5/5], Step [40/47], Loss: 1.5648, batch time: 0.03, accuracy:  50.00%
# ...
# Training round [390/400], Epoch [5/5], Step [40/47], Loss: 1.0892, batch time: 0.06, accuracy:  60.16%
# Training round [390/400], qnn_train_step: [100/500], loss: 1.26510751247406, accuracy: 56.0 %
# Training round [390/400], qnn_train_step: [200/500], loss: 1.2959251403808594, accuracy: 55.5 %
# Training round [390/400], qnn_train_step: [300/500], loss: 1.2829992771148682, accuracy: 54.8 %
# Training round [390/400], qnn_train_step: [400/500], loss: 1.2609270811080933, accuracy: 57.0 %
# Training round [390/400], qnn_train_step: [500/500], loss: 1.298365831375122, accuracy: 57.3 %
# -----------------------
# Training round [391/400], Epoch [1/5], Step [20/47], Loss: 1.3384, batch time: 0.06, accuracy:  53.91%
# Training round [391/400], Epoch [1/5], Step [40/47], Loss: 1.1668, batch time: 0.06, accuracy:  60.16%
# Training round [391/400], Epoch [2/5], Step [20/47], Loss: 1.2548, batch time: 0.07, accuracy:  49.22%
# Training round [391/400], Epoch [2/5], Step [40/47], Loss: 1.2644, batch time: 0.06, accuracy:  60.16%
# Training round [391/400], Epoch [3/5], Step [20/47], Loss: 1.2255, batch time: 0.06, accuracy:  57.03%
# Training round [391/400], Epoch [3/5], Step [40/47], Loss: 1.0905, batch time: 0.06, accuracy:  63.28%
# Training round [391/400], Epoch [4/5], Step [20/47], Loss: 1.1148, batch time: 0.06, accuracy:  59.38%
# Training round [391/400], Epoch [4/5], Step [40/47], Loss: 1.2462, batch time: 0.06, accuracy:  57.81%
# Training round [391/400], Epoch [5/5], Step [20/47], Loss: 1.3590, batch time: 0.06, accuracy:  50.78%
# Training round [391/400], Epoch [5/5], Step [40/47], Loss: 1.2249, batch time: 0.06, accuracy:  56.25%
# Training round [391/400], qnn_train_step: [100/500], loss: 1.2941704988479614, accuracy: 54.1 %
# Training round [391/400], qnn_train_step: [200/500], loss: 1.2888580560684204, accuracy: 55.2 %
# Training round [391/400], qnn_train_step: [300/500], loss: 1.2673135995864868, accuracy: 56.5 %
# Training round [391/400], qnn_train_step: [400/500], loss: 1.2627569437026978, accuracy: 56.8 %
# Training round [391/400], qnn_train_step: [500/500], loss: 1.8739620447158813, accuracy: 36.4 %
# -----------------------
# Training round [392/400], Epoch [1/5], Step [20/47], Loss: 1.2260, batch time: 0.07, accuracy:  60.16%
# Training round [392/400], Epoch [1/5], Step [40/47], Loss: 1.1589, batch time: 0.07, accuracy:  56.25%
# Training round [392/400], Epoch [2/5], Step [20/47], Loss: 1.3713, batch time: 0.06, accuracy:  50.00%
# Training round [392/400], Epoch [2/5], Step [40/47], Loss: 1.3772, batch time: 0.06, accuracy:  51.56%
# Training round [392/400], Epoch [3/5], Step [20/47], Loss: 1.3368, batch time: 0.06, accuracy:  52.34%
# Training round [392/400], Epoch [3/5], Step [40/47], Loss: 1.2874, batch time: 0.03, accuracy:  56.25%
# Training round [392/400], Epoch [4/5], Step [20/47], Loss: 1.4034, batch time: 0.03, accuracy:  57.81%
# Training round [392/400], Epoch [4/5], Step [40/47], Loss: 1.2422, batch time: 0.03, accuracy:  54.69%
# Training round [392/400], Epoch [5/5], Step [20/47], Loss: 1.3221, batch time: 0.03, accuracy:  50.78%
# Training round [392/400], Epoch [5/5], Step [40/47], Loss: 1.3282, batch time: 0.03, accuracy:  47.66%
# Training round [392/400], qnn_train_step: [100/500], loss: 1.2895320653915405, accuracy: 56.5 %
# Training round [392/400], qnn_train_step: [200/500], loss: 1.3305827379226685, accuracy: 54.9 %
# Training round [392/400], qnn_train_step: [300/500], loss: 1.264743685722351, accuracy: 58.2 %
# Training round [392/400], qnn_train_step: [400/500], loss: 1.2575002908706665, accuracy: 57.0 %
# Training round [392/400], qnn_train_step: [500/500], loss: 1.2933627367019653, accuracy: 57.1 %
# -----------------------
# Training round [393/400], Epoch [1/5], Step [20/47], Loss: 1.2886, batch time: 0.03, accuracy:  54.69%
# Training round [393/400], Epoch [1/5], Step [40/47], Loss: 1.1542, batch time: 0.03, accuracy:  64.06%
# Training round [393/400], Epoch [2/5], Step [20/47], Loss: 1.3614, batch time: 0.03, accuracy:  53.91%
# Training round [393/400], Epoch [2/5], Step [40/47], Loss: 1.3598, batch time: 0.03, accuracy:  54.69%
# Training round [393/400], Epoch [3/5], Step [20/47], Loss: 1.1096, batch time: 0.06, accuracy:  58.59%
# Training round [393/400], Epoch [3/5], Step [40/47], Loss: 1.0728, batch time: 0.03, accuracy:  64.84%
# Training round [393/400], Epoch [4/5], Step [20/47], Loss: 1.2401, batch time: 0.03, accuracy:  59.38%
# Training round [393/400], Epoch [4/5], Step [40/47], Loss: 1.2703, batch time: 0.06, accuracy:  62.50%
# Training round [393/400], Epoch [5/5], Step [20/47], Loss: 1.3638, batch time: 0.06, accuracy:  53.12%
# Training round [393/400], Epoch [5/5], Step [40/47], Loss: 1.3500, batch time: 0.06, accuracy:  54.69%
# Training round [393/400], qnn_train_step: [100/500], loss: 1.2649871110916138, accuracy: 55.3 %
# Training round [393/400], qnn_train_step: [200/500], loss: 1.3162989616394043, accuracy: 53.8 %
# Training round [393/400], qnn_train_step: [300/500], loss: 1.2621512413024902, accuracy: 55.3 %
# Training round [393/400], qnn_train_step: [400/500], loss: 2.1321024894714355, accuracy: 32.0 %
# Training round [393/400], qnn_train_step: [500/500], loss: 1.550368070602417, accuracy: 46.0 %
# -----------------------
# Training round [394/400], Epoch [1/5], Step [20/47], Loss: 1.4099, batch time: 0.06, accuracy:  50.78%
# Training round [394/400], Epoch [1/5], Step [40/47], Loss: 1.1968, batch time: 0.03, accuracy:  55.47%
# Training round [394/400], Epoch [2/5], Step [20/47], Loss: 1.1801, batch time: 0.06, accuracy:  59.38%
# Training round [394/400], Epoch [2/5], Step [40/47], Loss: 1.2932, batch time: 0.03, accuracy:  60.94%
# Training round [394/400], Epoch [3/5], Step [20/47], Loss: 1.2917, batch time: 0.06, accuracy:  57.03%
# Training round [394/400], Epoch [3/5], Step [40/47], Loss: 1.2357, batch time: 0.06, accuracy:  51.56%
# Training round [394/400], Epoch [4/5], Step [20/47], Loss: 1.1341, batch time: 0.06, accuracy:  59.38%
# Training round [394/400], Epoch [4/5], Step [40/47], Loss: 1.2584, batch time: 0.06, accuracy:  58.59%
# Training round [394/400], Epoch [5/5], Step [20/47], Loss: 1.4167, batch time: 0.06, accuracy:  54.69%
# Training round [394/400], Epoch [5/5], Step [40/47], Loss: 1.1867, batch time: 0.06, accuracy:  59.38%
# Training round [394/400], qnn_train_step: [100/500], loss: 1.2406760454177856, accuracy: 57.8 %
# Training round [394/400], qnn_train_step: [200/500], loss: 1.2559053897857666, accuracy: 57.5 %
# Training round [394/400], qnn_train_step: [300/500], loss: 1.2375506162643433, accuracy: 58.7 %
# Training round [394/400], qnn_train_step: [400/500], loss: 1.3618501424789429, accuracy: 53.3 %
# Training round [394/400], qnn_train_step: [500/500], loss: 1.3012713193893433, accuracy: 55.5 %
# -----------------------
# Training round [395/400], Epoch [1/5], Step [20/47], Loss: 1.1737, batch time: 0.06, accuracy:  63.28%
# Training round [395/400], Epoch [1/5], Step [40/47], Loss: 1.2870, batch time: 0.06, accuracy:  52.34%
# Training round [395/400], Epoch [2/5], Step [20/47], Loss: 1.2611, batch time: 0.06, accuracy:  55.47%
# Training round [395/400], Epoch [2/5], Step [40/47], Loss: 1.1622, batch time: 0.06, accuracy:  57.81%
# Training round [395/400], Epoch [3/5], Step [20/47], Loss: 1.2461, batch time: 0.06, accuracy:  55.47%
# Training round [395/400], Epoch [3/5], Step [40/47], Loss: 1.2368, batch time: 0.06, accuracy:  54.69%
# Training round [395/400], Epoch [4/5], Step [20/47], Loss: 1.1750, batch time: 0.06, accuracy:  60.94%
# Training round [395/400], Epoch [4/5], Step [40/47], Loss: 1.3106, batch time: 0.03, accuracy:  57.03%
# Training round [395/400], Epoch [5/5], Step [20/47], Loss: 1.3079, batch time: 0.06, accuracy:  56.25%
# Training round [395/400], Epoch [5/5], Step [40/47], Loss: 1.2144, batch time: 0.06, accuracy:  56.25%
# Training round [395/400], qnn_train_step: [100/500], loss: 1.3227944374084473, accuracy: 54.7 %
# Training round [395/400], qnn_train_step: [200/500], loss: 1.3328496217727661, accuracy: 54.4 %
# Training round [395/400], qnn_train_step: [300/500], loss: 1.3043782711029053, accuracy: 55.9 %
# Training round [395/400], qnn_train_step: [400/500], loss: 1.4301643371582031, accuracy: 48.8 %
# Training round [395/400], qnn_train_step: [500/500], loss: 1.3957940340042114, accuracy: 49.5 %
# -----------------------
# Training round [396/400], Epoch [1/5], Step [20/47], Loss: 1.3219, batch time: 0.06, accuracy:  56.25%
# Training round [396/400], Epoch [1/5], Step [40/47], Loss: 1.2000, batch time: 0.06, accuracy:  61.72%
# Training round [396/400], Epoch [2/5], Step [20/47], Loss: 1.4497, batch time: 0.06, accuracy:  52.34%
# Training round [396/400], Epoch [2/5], Step [40/47], Loss: 1.2075, batch time: 0.03, accuracy:  57.03%
# Training round [396/400], Epoch [3/5], Step [20/47], Loss: 1.2847, batch time: 0.06, accuracy:  54.69%
# Training round [396/400], Epoch [3/5], Step [40/47], Loss: 1.3377, batch time: 0.06, accuracy:  53.91%
# Training round [396/400], Epoch [4/5], Step [20/47], Loss: 1.3159, batch time: 0.06, accuracy:  52.34%
# Training round [396/400], Epoch [4/5], Step [40/47], Loss: 1.3090, batch time: 0.06, accuracy:  56.25%
# Training round [396/400], Epoch [5/5], Step [20/47], Loss: 1.1816, batch time: 0.06, accuracy:  56.25%
# Training round [396/400], Epoch [5/5], Step [40/47], Loss: 1.3440, batch time: 0.06, accuracy:  50.78%
# Training round [396/400], qnn_train_step: [100/500], loss: 1.2450140714645386, accuracy: 56.6 %
# Training round [396/400], qnn_train_step: [200/500], loss: 1.2593117952346802, accuracy: 54.4 %
# Training round [396/400], qnn_train_step: [300/500], loss: 1.2584197521209717, accuracy: 55.4 %
# Training round [396/400], qnn_train_step: [400/500], loss: 1.2168803215026855, accuracy: 56.5 %
# Training round [396/400], qnn_train_step: [500/500], loss: 1.2262463569641113, accuracy: 58.6 %
# -----------------------
# Training round [397/400], Epoch [1/5], Step [20/47], Loss: 1.3893, batch time: 0.03, accuracy:  53.12%
# Training round [397/400], Epoch [1/5], Step [40/47], Loss: 1.5248, batch time: 0.06, accuracy:  50.00%
# Training round [397/400], Epoch [2/5], Step [20/47], Loss: 1.3895, batch time: 0.06, accuracy:  51.56%
# Training round [397/400], Epoch [2/5], Step [40/47], Loss: 1.2841, batch time: 0.03, accuracy:  53.12%
# Training round [397/400], Epoch [3/5], Step [20/47], Loss: 1.2590, batch time: 0.06, accuracy:  54.69%
# Training round [397/400], Epoch [3/5], Step [40/47], Loss: 1.4079, batch time: 0.06, accuracy:  55.47%
# Training round [397/400], Epoch [4/5], Step [20/47], Loss: 1.1843, batch time: 0.06, accuracy:  57.03%
# Training round [397/400], Epoch [4/5], Step [40/47], Loss: 1.1502, batch time: 0.06, accuracy:  61.72%
# Training round [397/400], Epoch [5/5], Step [20/47], Loss: 1.2075, batch time: 0.03, accuracy:  58.59%
# Training round [397/400], Epoch [5/5], Step [40/47], Loss: 1.2718, batch time: 0.06, accuracy:  53.91%
# Training round [397/400], qnn_train_step: [100/500], loss: 1.2733964920043945, accuracy: 55.5 %
# Training round [397/400], qnn_train_step: [200/500], loss: 1.3443788290023804, accuracy: 51.9 %
# Training round [397/400], qnn_train_step: [300/500], loss: 2.354588508605957, accuracy: 40.3 %
# Training round [397/400], qnn_train_step: [400/500], loss: 1.292798399925232, accuracy: 55.0 %
# Training round [397/400], qnn_train_step: [500/500], loss: 1.2466076612472534, accuracy: 56.7 %
# -----------------------
# Training round [398/400], Epoch [1/5], Step [20/47], Loss: 1.2480, batch time: 0.06, accuracy:  53.91%
# Training round [398/400], Epoch [1/5], Step [40/47], Loss: 1.3705, batch time: 0.03, accuracy:  49.22%
# Training round [398/400], Epoch [2/5], Step [20/47], Loss: 1.1424, batch time: 0.06, accuracy:  63.28%
# Training round [398/400], Epoch [2/5], Step [40/47], Loss: 1.3450, batch time: 0.06, accuracy:  51.56%
# Training round [398/400], Epoch [3/5], Step [20/47], Loss: 1.3236, batch time: 0.06, accuracy:  54.69%
# Training round [398/400], Epoch [3/5], Step [40/47], Loss: 1.2308, batch time: 0.06, accuracy:  57.03%
# Training round [398/400], Epoch [4/5], Step [20/47], Loss: 1.3599, batch time: 0.06, accuracy:  55.47%
# Training round [398/400], Epoch [4/5], Step [40/47], Loss: 1.2103, batch time: 0.06, accuracy:  60.16%
# Training round [398/400], Epoch [5/5], Step [20/47], Loss: 1.3696, batch time: 0.06, accuracy:  53.91%
# Training round [398/400], Epoch [5/5], Step [40/47], Loss: 1.2708, batch time: 0.05, accuracy:  53.12%
# Training round [398/400], qnn_train_step: [100/500], loss: 1.2237935066223145, accuracy: 56.7 %
# Training round [398/400], qnn_train_step: [200/500], loss: 1.2751089334487915, accuracy: 56.0 %
# Training round [398/400], qnn_train_step: [300/500], loss: 1.21421480178833, accuracy: 57.2 %
# Training round [398/400], qnn_train_step: [400/500], loss: 1.2077604532241821, accuracy: 58.7 %
# Training round [398/400], qnn_train_step: [500/500], loss: 1.2475550174713135, accuracy: 57.1 %
# -----------------------
# Training round [399/400], Epoch [1/5], Step [20/47], Loss: 1.2491, batch time: 0.11, accuracy:  52.34%
# Training round [399/400], Epoch [1/5], Step [40/47], Loss: 1.2258, batch time: 0.03, accuracy:  58.59%
# Training round [399/400], Epoch [2/5], Step [20/47], Loss: 1.3045, batch time: 0.06, accuracy:  53.12%
# Training round [399/400], Epoch [2/5], Step [40/47], Loss: 1.2261, batch time: 0.06, accuracy:  57.81%
# Training round [399/400], Epoch [3/5], Step [20/47], Loss: 1.2750, batch time: 0.06, accuracy:  55.47%
# Training round [399/400], Epoch [3/5], Step [40/47], Loss: 1.2102, batch time: 0.04, accuracy:  62.50%
# Training round [399/400], Epoch [4/5], Step [20/47], Loss: 1.1991, batch time: 0.03, accuracy:  56.25%
# Training round [399/400], Epoch [4/5], Step [40/47], Loss: 1.2015, batch time: 0.03, accuracy:  57.81%
# Training round [399/400], Epoch [5/5], Step [20/47], Loss: 1.2764, batch time: 0.03, accuracy:  56.25%
# Training round [399/400], Epoch [5/5], Step [40/47], Loss: 1.3096, batch time: 0.03, accuracy:  53.91%
# Training round [399/400], qnn_train_step: [100/500], loss: 1.2552464008331299, accuracy: 56.7 %
# Training round [399/400], qnn_train_step: [200/500], loss: 1.2781827449798584, accuracy: 56.5 %
# Training round [399/400], qnn_train_step: [300/500], loss: 1.247414231300354, accuracy: 57.5 %
# Training round [399/400], qnn_train_step: [400/500], loss: 1.234618902206421, accuracy: 58.1 %
# Training round [399/400], qnn_train_step: [500/500], loss: 1.2471058368682861, accuracy: 58.7 %
# -----------------------
# Training round [400/400], Epoch [1/5], Step [20/47], Loss: 1.3615, batch time: 0.03, accuracy:  53.12%
# Training round [400/400], Epoch [1/5], Step [40/47], Loss: 1.1719, batch time: 0.03, accuracy:  53.12%
# Training round [400/400], Epoch [2/5], Step [20/47], Loss: 1.2327, batch time: 0.03, accuracy:  59.38%
# Training round [400/400], Epoch [2/5], Step [40/47], Loss: 1.3034, batch time: 0.03, accuracy:  58.59%
# Training round [400/400], Epoch [3/5], Step [20/47], Loss: 1.2884, batch time: 0.03, accuracy:  54.69%
# Training round [400/400], Epoch [3/5], Step [40/47], Loss: 1.2874, batch time: 0.03, accuracy:  60.94%
# Training round [400/400], Epoch [4/5], Step [20/47], Loss: 1.3681, batch time: 0.07, accuracy:  51.56%
# Training round [400/400], Epoch [4/5], Step [40/47], Loss: 1.1335, batch time: 0.05, accuracy:  63.28%
# Training round [400/400], Epoch [5/5], Step [20/47], Loss: 1.1954, batch time: 0.08, accuracy:  54.69%
# Training round [400/400], Epoch [5/5], Step [40/47], Loss: 1.3415, batch time: 0.03, accuracy:  54.69%
# Training round [400/400], qnn_train_step: [100/500], loss: 1.254656434059143, accuracy: 57.2 %
# Training round [400/400], qnn_train_step: [200/500], loss: 1.3248118162155151, accuracy: 54.6 %
# Training round [400/400], qnn_train_step: [300/500], loss: 1.2417500019073486, accuracy: 57.7 %
# Training round [400/400], qnn_train_step: [400/500], loss: 5.031083106994629, accuracy: 24.2 %
# Training round [400/400], qnn_train_step: [500/500], loss: 1.3976705074310303, accuracy: 51.7 %

# %%
plt.plot(loss_list)
plt.ylim(0.5, 2.5)
plt.show()

# %%
# Testing train loop
qt_model.eval()
correct = 0
total = 0
loss_train_list = []
with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = qt_model(images, qnn_parameters)
        loss_train = criterion(outputs, labels).cpu().detach().numpy()
        loss_train_list.append(loss_train)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")

# Testing loop
qt_model.eval()
correct = 0
total = 0
loss_test_list = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = qt_model(images, qnn_parameters)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))
# Out:
# Accuracy on the train set: 56.17%
# Loss on the train set: 1.27
# Accuracy on the test set: 62.00%
# Loss on the test set: 1.19
# Generalization error: -0.08398974

# %%
# # Testing train loop
# model.eval()
# correct = 0
# total = 0
# loss_train_list = []
# with torch.no_grad():
#     for images, labels in train_loader:
#         images, labels = images.to(device), labels.to(device)  # Move data to GPU
#         outputs = model(images)
#         loss_train = criterion(outputs, labels).cpu().detach().numpy()
#         loss_train_list.append(loss_train)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
# print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")

# # Testing loop
# model.eval()
# correct = 0
# total = 0
# loss_test_list = []

# with torch.no_grad():
#     for images, labels in val_loader:
#         images, labels = images.to(device), labels.to(device)  # Move data to GPU
#         outputs = model(images)
#         loss_test = criterion(outputs, labels).cpu().detach().numpy()
#         loss_test_list.append(loss_test)

#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

# print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
# print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

# print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))

# %%
# def fit(
#     epochs: int,
#     lr: float,
#     model: torch.nn.Module,
#     train_loader: DataLoader,
#     val_loader: DataLoader,
#     bs: BosonSampler,
#     opt_func=torch.optim.SGD,
#     save_csv: bool = True,
#     csv_path: str = "training_history"
# ):
#     """
#     Trains the model for a specified number of epochs, evaluates on validation data,
#     and optionally saves the training history to a CSV file with a timestamp.

#     Args:
#         epochs (int): Number of epochs to train.
#         lr (float): Learning rate.
#         model (torch.nn.Module): The neural network model to train.
#         train_loader (DataLoader): DataLoader for training data.
#         val_loader (DataLoader): DataLoader for validation data.
#         bs (BosonSampler): BosonSampler instance for embedding.
#         opt_func (torch.optim.Optimizer, optional): Optimizer constructor. Defaults to torch.optim.SGD.
#         save_csv (bool, optional): Whether to save the training history to a CSV file. Defaults to True.
#         csv_path (str, optional): Base path/name for the CSV file. A timestamp will be appended. Defaults to "training_history".

#     Returns:
#         dict: A dictionary containing training and validation metrics per epoch.
#     """
#     # Initialize optimizer
#     optimizer = opt_func(model.parameters(), lr=lr)
#     criterion = torch.nn.CrossEntropyLoss()

#     # Initialize history dictionary
#     history = {
#         'epoch': [],
#         'train_loss': [],
#         'train_acc': [],
#         'val_loss': [],
#         'val_acc': []
#     }

#     # Determine the device from the model
#     device = next(model.parameters()).device
#     print(f"Training on device: {device}")

#     # Create a progress bar for epochs
#     epoch_bar = tqdm(range(1, epochs + 1), desc="Training Progress", unit="epoch")

#     for epoch in epoch_bar:
#         model.train()
#         running_loss = 0.0
#         running_corrects = 0
#         total_samples = 0

#         # Iterate over training data
#         for batch in train_loader:
#             if model.embedding_size:
#                 images, labels = batch
#                 # Move images and labels to the device
#                 images = images.to(device)
#                 labels = labels.to(device)

#                 # Generate embeddings and move them to the device
#                 embs = bs.embed(images, n_sample=1000).to(device)

#                 # Forward pass with embeddings
#                 outputs = model(images, emb=embs.unsqueeze(0))
#             else:
#                 images, labels = batch
#                 # Move images and labels to the device
#                 images = images.to(device)
#                 labels = labels.to(device)

#                 # Forward pass without embeddings
#                 outputs = model(images)

#             # Compute loss
#             loss = criterion(outputs, labels)

#             # Compute accuracy
#             _, preds = torch.max(outputs, 1)
#             acc = torch.sum(preds == labels.data).item()

#             # Backward pass and optimization
#             optimizer.zero_grad()
#             loss.backward()
#             optimizer.step()

#             # Accumulate loss and accuracy
#             running_loss += loss.item() * images.size(0)
#             running_corrects += acc
#             total_samples += images.size(0)

#         # Calculate epoch metrics
#         epoch_train_loss = running_loss / total_samples
#         epoch_train_acc = running_corrects / total_samples

#         # Validation phase
#         model.eval()
#         val_running_loss = 0.0
#         val_running_corrects = 0
#         val_total_samples = 0

#         with torch.no_grad():
#             for batch in val_loader:
#                 if model.embedding_size:
#                     images, labels = batch
#                     # Move images and labels to the device
#                     images = images.to(device)
#                     labels = labels.to(device)

#                     # Generate embeddings and move them to the device
#                     embs = bs.embed(images, n_sample=1000).to(device)

#                     # Forward pass with embeddings
#                     outputs = model(images, emb=embs.unsqueeze(0))
#                 else:
#                     images, labels = batch
#                     # Move images and labels to the device
#                     images = images.to(device)
#                     labels = labels.to(device)

#                     # Forward pass without embeddings
#                     outputs = model(images)

#                 # Compute loss
#                 loss = criterion(outputs, labels)

#                 # Compute accuracy
#                 _, preds = torch.max(outputs, 1)
#                 acc = torch.sum(preds == labels.data).item()

#                 # Accumulate loss and accuracy
#                 val_running_loss += loss.item() * images.size(0)
#                 val_running_corrects += acc
#                 val_total_samples += images.size(0)

#         # Calculate validation metrics
#         epoch_val_loss = val_running_loss / val_total_samples
#         epoch_val_acc = val_running_corrects / val_total_samples

#         # Update history
#         history['epoch'].append(epoch)
#         history['train_loss'].append(epoch_train_loss)
#         history['train_acc'].append(epoch_train_acc)
#         history['val_loss'].append(epoch_val_loss)
#         history['val_acc'].append(epoch_val_acc)

#         # Update the progress bar description
#         epoch_bar.set_postfix({
#             'Train Loss': f"{epoch_train_loss:.4f}",
#             'Train Acc': f"{epoch_train_acc:.4f}",
#             'Val Loss': f"{epoch_val_loss:.4f}",
#             'Val Acc': f"{epoch_val_acc:.4f}"
#         })

#     # Save history to CSV with timestamp
#     if save_csv:
#         timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#         csv_filename = f"{csv_path}_{timestamp}.csv"
#         history_df = pd.DataFrame(history)
#         history_df.to_csv(csv_filename, index=False)
#         print(f"\nTraining history saved to '{csv_filename}'.")

#     return history
